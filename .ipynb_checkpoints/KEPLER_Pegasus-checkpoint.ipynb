# %%
# !pip3 install virtualenv
# !virtualenv my_env
# !python -m ipykernel install --user --name=my_env

# %%
# !pip3 install torch==1.10.1+cu113 torchvision==0.11.2+cu113 torchaudio==0.10.1+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
# !pip3 install transformers
# !pip3 install sentencepiece

# %%
import json
import numpy as np
import pandas as pd
import torch

from transformers import PegasusModel, PegasusForConditionalGeneration, PegasusTokenizerFast, AdamW, get_scheduler
from torch.utils.data import Dataset, DataLoader
from tqdm.auto import tqdm

# %% [markdown]
# ##### Load Train Dataset, Tokenizer & Model

# %%
with open('./train_dataset.json', 'r') as f:
    text_data = json.load(f)
with open('./triplet_train_dataset.json', 'r') as f:
    graph_data = json.load(f)
graph_data = graph_data['negatives'][:4263] + graph_data['hard_negatives'][:2133]

# %%
model_name = 'google/pegasus-large'
torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'
tokenizer = PegasusTokenizerFast.from_pretrained(model_name)
model = PegasusForConditionalGeneration.from_pretrained(model_name, return_dict=True).to(torch_device)

# %%
list(model.parameters())
# Out:
# [Parameter containing:
#  tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [-5.8086e-01,  8.9593e-04,  1.7132e+00,  ..., -1.5437e-01,
#            3.5809e-01, -1.2001e-01],
#          [ 4.1956e-02,  4.1889e-03,  2.5050e+00,  ...,  1.3245e-01,
#           -3.1036e-01, -1.5134e-01],
#          ...,
#          [-3.1217e-01,  7.3458e-04,  1.1099e-01,  ..., -6.3274e-01,
#           -2.3137e+00, -2.5253e-01],
#          [ 6.5283e-01,  1.1337e-02,  3.4026e-01,  ..., -6.7358e-01,
#            1.0317e-01, -6.6524e-01],
#          [ 3.7179e-01, -4.0305e-02,  6.3053e-01,  ...,  6.4149e-01,
#           -1.1383e+00, -5.8333e-01]], requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.0000,  0.0000,  0.0000,  ...,  1.0000,  1.0000,  1.0000],
#          [ 0.8415,  0.8317,  0.8219,  ...,  1.0000,  1.0000,  1.0000],
#          [ 0.9093,  0.9236,  0.9364,  ...,  1.0000,  1.0000,  1.0000],
#          ...,
#          [ 0.0176, -0.5887, -0.9995,  ...,  0.9942,  0.9944,  0.9946],
#          [-0.8318, -0.9992, -0.5446,  ...,  0.9942,  0.9944,  0.9946],
#          [-0.9165, -0.5208,  0.3790,  ...,  0.9942,  0.9944,  0.9946]]),
#  Parameter containing:
#  tensor([[-0.1574, -0.0271, -0.1016,  ...,  0.0807,  0.0864,  0.2258],
#          [-0.0605,  0.0177,  0.1535,  ..., -0.0202, -0.0147, -0.0067],
#          [-0.3156, -0.0006,  0.0614,  ...,  0.1037, -0.4322, -0.0822],
#          ...,
#          [ 0.0668, -0.0333, -0.0410,  ...,  0.1403, -0.3487,  0.1291],
#          [ 0.1188,  0.0228,  0.0467,  ..., -0.2489, -0.1608, -0.1576],
#          [-0.1753,  0.0171, -0.0603,  ...,  0.1028, -0.2544, -0.2925]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0., 0., 0.,  ..., 0., 0., 0.], requires_grad=True),
#  Parameter containing:
#  tensor([
],
#         requires_grad=True),
#  Parameter containing:
#  tensor([  9.4879, -69.6476,  -7.8813,  ...,  -5.4499,   2.1274,   0.7397],
#         requires_grad=True),
#  Parameter containing:
#  tensor([4.3309, 4.5348, 4.2496,  ..., 4.0724, 3.1521, 2.9960],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.5858,  0.5105, -0.2433,  ...,  0.4776,  0.3044,  0.2585],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0.6979, 0.1754, 0.5850,  ..., 0.6502, 0.4479, 0.5241],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0.0318, 0.0111, 0.2093,  ..., 0.0440, 0.0162, 0.0407],
#         requires_grad=True)]

# %% [markdown]
# ##### Define Custom Dataset, DataLoader

# %%
class SubprocessDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels
    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels['input_ids'][idx]) # torch.tensor(self.labels[idx])
        return item # input_ids, attention_mask, labels
    def __len__(self):
        return len(self.labels['input_ids']) # len(self.labels)

# %%
class GraphDataset(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.encodings = encodings
    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        # 1 training step - see if decoder weights change
        item['labels'] = torch.tensor(self.encodings['input_ids'][idx])
        return item # input_ids, attention_mask, labels
    def __len__(self):
        return len(self.encodings['input_ids']) # len(self.labels)

# %%
def tokenize_data(tasks, texts, labels):
    graph_encodings = tokenizer(tasks, truncation=True, padding=True)
    encodings = tokenizer(texts, truncation=True, padding=True)
    decodings = tokenizer(labels, truncation=True, padding=True)
    graphdata_tokenized = GraphDataset(graph_encodings)
    subprocess_tokenized = SubprocessDataset(encodings, decodings)
    return graphdata_tokenized, subprocess_tokenized

# %%
def get_eos_idx(batch):
    for input_ids in batch['input_ids']:
        eos_id = input_ids == 1
        idx = eos_id.nonzero()[0]
        if 'eos_idx' in locals():
            eos_idx = torch.cat((eos_idx, idx), 0)
        else:
            eos_idx = eos_id.nonzero()[0]
    return eos_idx

# %% [markdown]
# ### KEPLER Pegasus Model
# https://pytorch.org/docs/stable/_modules/torch/nn/modules/loss.html#TripletMarginLoss

# %%
import torch.nn as nn
import torch.nn.functional as F

class KeplerPegasusModel(nn.TripletMarginLoss):
    
    def __init__(self, model, margin: float = 1.0, p: float = 2., eps: float = 1e-6, swap: bool = False, size_average=None,
                 reduce=None, reduction: str = 'mean'):
        super().__init__(margin, p, eps, swap, size_average, reduce, reduction)
        self.model = model
        
    def forward(self, graphdata_eos_idx, graphdata_batch, subprocess_batch):
        # Triplet margin loss
        model_output = self.model(**graphdata_batch)
        encoder_output = model_output.encoder_last_hidden_state
        anchor = encoder_output[0][graphdata_eos_idx[0]]
        positive = encoder_output[1][graphdata_eos_idx[1]]
        negative = encoder_output[2][graphdata_eos_idx[2]]
        triplet_margin_loss = F.triplet_margin_loss(anchor, positive, negative, margin=self.margin, p=self.p,
                                 eps=self.eps, swap=self.swap, reduction=self.reduction)
        # Pegasus loss
#         MLM_output = self.model(**subprocess_batch)
        
#         loss = MLM_output.loss + triplet_margin_loss 
        # monitor losses
        
        return triplet_margin_loss

# %%
graphdata_train_dataset, subprocess_train_dataset = tokenize_data(graph_data, text_data['document'], text_data['summary'])

graphdata_train_dataloader = DataLoader(
    graphdata_train_dataset, shuffle=False, batch_size=3
#     num_workers=4
)
subprocess_train_dataloader = DataLoader(
    subprocess_train_dataset, shuffle=True, batch_size=1
#     num_workers=4
)

for graphdata_batch, subprocess_batch in zip(graphdata_train_dataloader, subprocess_train_dataloader):
    break
print({k: v.shape for k, v in graphdata_batch.items()})
print({k: v.shape for k, v in subprocess_batch.items()})
# Out:
# {'input_ids': torch.Size([3, 34]), 'attention_mask': torch.Size([3, 34]), 'labels': torch.Size([3, 34])}
# {'input_ids': torch.Size([1, 849]), 'attention_mask': torch.Size([1, 849]), 'labels': torch.Size([1, 134])}

# %%
optimizer = AdamW(model.parameters(), weight_decay=0.01, lr=5e-5)

num_epochs = 10
num_training_steps = num_epochs * len(graphdata_train_dataloader)
lr_scheduler = get_scheduler(
    "linear",
    optimizer=optimizer,
    num_warmup_steps=500,
    num_training_steps=num_training_steps,
)
print(num_training_steps)
# Out:
# 21320

# %%
def save(model, optimizer, output_model):
    torch.save({
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict()
    }, output_model)

# # load
# checkpoint = torch.load(output_model, map_location='cpu')
# model.load_state_dict(checkpoint['model_state_dict'])
# optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# %%
progress_bar = tqdm(range(num_training_steps))

model.train()
for epoch in range(num_epochs):
    for i, (graphdata_batch, subprocess_batch) in enumerate(zip(graphdata_train_dataloader, subprocess_train_dataloader)):        
        graphdata_eos_idx = get_eos_idx(graphdata_batch)
        graphdata_batch = {k: v.to(torch_device) for k, v in graphdata_batch.items()}
        subprocess_batch = {k: v.to(torch_device) for k, v in subprocess_batch.items()}
        kepler_pegasus_model = KeplerPegasusModel(model)
        loss = kepler_pegasus_model(graphdata_eos_idx, graphdata_batch, subprocess_batch)
        loss.backward()

        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        progress_bar.update(1)
        if (i+1) % 100 == 0:
            loss_log = f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{num_step}], Loss: {loss.item():.4f}'
            print (loss_log)
            break
#     if epoch % 2 == 0:
#         output_model = './models/kepler_pegasus_{}_epoch.pth'.format(epoch)
#         save(model, optimizer, output_model)
# Out:
#   0%|          | 0/21320 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/wn/y90bwflx3dd_bf70j8_n0z_r0000gn/T/ipykernel_58237/3984638116.py in <module>
#      16         progress_bar.update(1)
#      17         if (i+1) % 100 == 0:
# ---> 18             loss_log = f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{num_step}], Loss: {loss.item():.4f}'
#      19             print (loss_log)
#      20             break
#
# NameError: name 'num_step' is not defined

# %%
i = 0 
for param in model.parameters():
    print(type(param), param.size())
    i += 1
print(i)
# Out:
# <class 'torch.nn.parameter.Parameter'> torch.Size([96103, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024,
],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0., 0., 0.,  ..., 0., 0., 0.], requires_grad=True),
#  Parameter containing:
#  tensor([[ 5.4802e-01,  1.7682e+00,  2.2793e+00,  ...,  1.2548e+00,
#            4.6002e-01,  8.8874e-01],
#          [-7.5110e-01, -2.5969e-01, -9.1595e-01,  ...,  1.1717e+00,
#           -7.0235e-01, -1.2588e+00],
#          [-1.0065e+00, -2.3326e-01,  7.2125e-01,  ..., -9.3784e-01,
#            6.7895e-01, -5.6495e-02],
#          ...,
#          [-1.3950e+00, -1.0698e-01, -1.0942e+00,  ...,  8.2279e-01,
#            4.0368e-04, -4.0546e-01],
#          [ 1.1677e+00,  5.4296e-01,  1.3000e+00,  ..., -3.3278e-01,
#           -9.4725e-01,  2.7194e+00],
#          [-2.2041e+00,  1.1179e+00, -9.1389e-02,  ..., -5.2201e-01,
#           -4.3238e-01,  1.0636e+00]], requires_grad=True),
#  Parameter containing:
#  tensor([0., 0., 0.,  ..., 0., 0., 0.], requires_grad=True),
#  Parameter containing:
#  tensor([0.2835, 0.7367, 0.4137,  ..., 0.2914, 0.2943, 0.2942],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.0346,  0.0696, -0.0352,  ...,  0.0267,  0.0271,  0.0333],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.8142,  0.4449, -0.6297,  ..., -0.2346, -1.1304, -0.1365],
#          [-0.3567, -0.1558,  0.0368,  ..., -0.0033, -0.3952,  0.2438],
#          [ 0.1553,  0.0234, -0.4796,  ...,  0.3068,  0.3784,  0.0249],
#          ...,
#          [ 0.0673,  0.0321, -0.1377,  ..., -0.0045,  0.6537,  0.1849],
#          [ 0.0791,  0.0886,  0.8673,  ...,  0.0545,  0.8118, -0.4419],
#          [ 0.1327, -0.1567,  0.0447,  ..., -0.0229,  0.3394, -0.8922]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-0.1135, -0.0005, -0.1175,  ..., -0.1360, -0.0291,  0.0085],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.4497,  0.7690, -0.3658,  ..., -0.0251,  0.2841, -0.6373],
#          [-0.7337, -2.0492, -0.5186,  ..., -3.0517,  0.3779,  0.9041],
#          [-0.7010, -0.1034, -0.5511,  ...,  0.5838, -0.0622,  0.3409],
#          ...,
#          [-0.1821, -0.1102,  0.6952,  ...,  0.5123, -0.4601,  0.1992],
#          [ 0.4793, -0.1837, -0.4549,  ..., -1.2702,  0.1318, -0.6040],
#          [ 1.0425, -0.0387,  0.5133,  ..., -0.1092, -0.8561, -0.3839]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([  9.4879, -69.6476,  -7.8813,  ...,  -5.4499,   2.1274,   0.7397],
#         requires_grad=True),
#  Parameter containing:
#  tensor([4.3309, 4.5348, 4.2496,  ..., 4.0724, 3.1521, 2.9960],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.5858,  0.5105, -0.2433,  ...,  0.4776,  0.3044,  0.2585],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0.6979, 0.1754, 0.5850,  ..., 0.6502, 0.4479, 0.5241],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0.0318, 0.0111, 0.2093,  ..., 0.0440, 0.0162, 0.0407],
#         requires_grad=True)]

# %%
# model.eval()
list(model.parameters())
# Out:
# [Parameter containing:
#  tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [-5.8100e-01,  9.4649e-04,  1.7132e+00,  ..., -1.5443e-01,
#            3.5815e-01, -1.2020e-01],
#          [ 4.1956e-02,  4.1889e-03,  2.5050e+00,  ...,  1.3245e-01,
#           -3.1036e-01, -1.5134e-01],
#          ...,
#          [-3.1217e-01,  7.3458e-04,  1.1099e-01,  ..., -6.3274e-01,
#           -2.3137e+00, -2.5253e-01],
#          [ 6.5282e-01,  1.1337e-02,  3.4026e-01,  ..., -6.7357e-01,
#            1.0317e-01, -6.6523e-01],
#          [ 3.7178e-01, -4.0305e-02,  6.3052e-01,  ...,  6.4148e-01,
#           -1.1383e+00, -5.8333e-01]], requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.0000,  0.0000,  0.0000,  ...,  1.0000,  1.0000,  1.0000],
#          [ 0.8415,  0.8317,  0.8219,  ...,  1.0000,  1.0000,  1.0000],
#          [ 0.9093,  0.9236,  0.9364,  ...,  1.0000,  1.0000,  1.0000],
#          ...,
#          [ 0.0176, -0.5887, -0.9995,  ...,  0.9942,  0.9944,  0.9946],
#          [-0.8318, -0.9992, -0.5446,  ...,  0.9942,  0.9944,  0.9946],
#          [-0.9165, -0.5208,  0.3790,  ...,  0.9942,  0.9944,  0.9946]]),
#  Parameter containing:
#  tensor([[-0.1574, -0.0270, -0.1017,  ...,  0.0805,  0.0863,  0.2258],
#          [-0.0604,  0.0176,  0.1533,  ..., -0.0200, -0.0147, -0.0069],
#          [-0.3154, -0.0006,  0.0613,  ...,  0.1037, -0.4320, -0.0823],
#          ...,
#          [ 0.0669, -0.0332, -0.0410,  ...,  0.1401, -0.3487,  0.1291],
#          [ 0.1188,  0.0229,  0.0467,  ..., -0.2488, -0.1608, -0.1576],
#          [-0.1753,  0.0170, -0.0602,  ...,  0.1029, -0.2543, -0.2925]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-1.5619e-08, -7.4050e-09, -9.8313e-09,  ..., -4.5560e-08,
#           2.2425e-08,  5.6998e-09], requires_grad=True),
#  Parameter containing:
#  tensor([[-0.0917, -0.0110, -0.0401,  ..., -0.0885, -0.0908, -0.0710],
#          [-0.1168, -0.0187,  0.0553,  ...,  0.0034, -0.0889, -0.1359],
#          [ 0.1667, -0.0090,  0.0374,  ..., -0.0691,  0.0025, -0.0708],
#          ...,
#          [ 0.0051,  0.0101, -0.0134,  ...,  0.0532,  0.1137, -0.0402],
#          [-0.0301, -0.0116, -0.0242,  ...,  0.1990, -0.1088,  0.3894],
#          [-0.0382,  0.0038, -0.0080,  ...,  0.1000, -0.2227, -0.2748]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 1.4956e-04,  3.1298e-05,  5.7943e-05,  ..., -4.3838e-05,
#           1.4739e-04,  2.5103e-05], requires_grad=True),
#  Parameter containing:
#  tensor([[-5.0655e-02, -4.4391e-02, -2.3586e-01,  ..., -7.9028e-02,
#            9.5656e-02,  1.3893e-01],
#          [-2.9780e-02, -1.0536e-02,  2.0918e-01,  ...,  8.8228e-02,
#            1.8160e-01, -7.0824e-02],
#          [-3.4135e-01, -8.7096e-02, -1.4987e-02,  ..., -1.7972e-01,
#           -5.2181e-01, -2.9121e-02],
#          ...,
#          [-2.5058e-01,  1.4750e-02,  2.2419e-04,  ...,  1.2658e-02,
#            2.4565e-01, -8.5965e-02],
#          [-1.4762e-01, -1.6015e-02, -6.8488e-02,  ...,  1.0789e-01,
#            1.4133e-01,  1.0465e-01],
#          [-1.4978e-01, -4.7745e-02,  9.1718e-02,  ...,  2.3595e-01,
#            1.5153e-01,  2.9793e-01]], requires_grad=True),
#  Parameter containing:
#  tensor([-2.1593e-05,  9.2417e-05,  1.9704e-04,  ...,  6.4601e-05,
#           1.1414e-04, -1.3560e-04], requires_grad=True),
#  Parameter containing:
#  tensor([[ 0
],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 1.5185e-08,  7.4046e-09,  3.2453e-09,  ..., -2.1292e-08,
#          -1.7626e-08, -7.9604e-09], requires_grad=True),
#  Parameter containing:
#  tensor([[-0.1280, -0.0805,  0.0257,  ...,  0.2737, -0.1267, -0.1333],
#          [ 0.2358, -0.0221, -0.0506,  ...,  0.0980, -0.1340, -0.0935],
#          [ 0.1287,  0.0055, -0.0006,  ..., -0.1460,  0.2122, -0.0387],
#          ...,
#          [ 0.0479, -0.0742, -0.1049,  ..., -0.1027,  0.1185, -0.0783],
#          [ 0.1296,  0.0463, -0.0090,  ..., -0.0214, -0.0840,  0.1174],
#          [ 0.1266, -0.0258, -0.0029,  ..., -0.1909,  0.2195,  0.2578]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 5.8016e-05,  1.2114e-04, -8.8942e-06,  ...,  1.7503e-05,
#          -5.0152e-05,  4.8947e-05], requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.1068,  0.0535,  0.1483,  ...,  0.0398, -0.0153, -0.2502],
#          [-0.1835, -0.0443, -0.0263,  ...,  0.1759, -0.2975,  0.0098],
#          [-0.1614,  0.0881, -0.0267,  ...,  0.1799,  0.0249, -0.1862],
#          ...,
#          [ 0.1099,  0.0702, -0.3587,  ..., -0.0761,  0.2386, -0.1632],
#          [-0.0498,  0.0392, -0.0166,  ..., -0.1043,  0.0268,  0.5940],
#          [ 0.3587,  0.0178,  0.2803,  ..., -0.1888, -0.1283,  0.3307]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-7.8517e-05, -1.8680e-04, -2.0824e-05,  ..., -1.3706e-04,
#           1.8951e-04, -1.2559e-04], requires_grad=True),
#  Parameter containing:
#  tensor([[-4.6878e-02, -1.8733e-01,  1.4608e-01,  ..., -1.8263e-01,
#            5.0413e-01,  3.2356e-01],
#          [-1.3246e-02,  5.8640e-04,  7.0125e-03,  ..., -3.0527e-03,
#           -2.7710e-02, -2.7260e-02],
#          [-2.0939e-01,  3.5962e-01, -4.4958e-01,  ...,  1.1895e+00,
#           -2.7763e-01, -1.9579e-01],
#          ...,
#          [ 2.1444e-01, -4.3550e-01, -1.9108e-01,  ...,  3.6488e-01,
#            3.5721e-01, -1.8608e-01],
#          [-6.5296e-01,  1.0417e-01,  3.5673e-02,  ...,  3.6390e-02,
#           -1.7517e-01,  9.7350e-02],
#          [-1.6802e-01, -2.1691e-01,  8.4506e-02,  ...,  4.7460e-01,
#           -3.1717e-01,  1.6004e-01]], requires_grad=True),
#  Parameter containing:
#  tensor([-1.7020e-04,  3.7885e-05,  6.1460e-05,  ...,  4.7643e-05,
#           8.2472e-05,  4.0254e-05], requires_grad=True),
#  Parameter containing:
#  tensor([0.1774, 1.8081, 0.0173,  ..., 0.1404, 0.1136, 0.1701],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0.0078, 0.0289, 0.1381,  ..., 0.0071, 0.0003, 0.0051],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[
],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-5.3889e-05, -1.1449e-04,  5.7359e-05,  ..., -1.2134e-04,
#          -5.6396e-05, -8.8721e-05], requires_grad=True),
#  Parameter containing:
#  tensor([[ 8.5186e-02, -1.7313e-01, -1.9150e-01,  ...,  6.4742e-02,
#            6.0587e-02, -4.1123e-02],
#          [-9.0684e-02,  6.8449e-01,  2.3666e-01,  ..., -1.1136e-01,
#           -4.8707e-02, -1.8381e-02],
#          [ 7.0012e-02, -2.9862e-01,  2.7726e-02,  ..., -1.3829e-01,
#           -1.8376e-01,  3.3912e-01],
#          ...,
#          [ 3.9414e-01, -3.9134e-03,  1.1020e-01,  ...,  3.2108e-01,
#            6.9563e-02,  2.6071e-02],
#          [-1.4900e-01,  3.2098e-02, -1.8185e-01,  ...,  4.4513e-02,
#            2.4514e-01,  1.7900e-01],
#          [ 2.2340e-01,  7.5960e-02, -3.4485e-01,  ..., -2.3532e-01,
#           -1.1104e-01,  9.3130e-05]], requires_grad=True),
#  Parameter containing:
#  tensor([ 1.8355e-04,  1.5477e-04, -1.0351e-04,  ...,  4.0107e-05,
#          -5.9872e-05,  5.1393e-05], requires_grad=True),
#  Parameter containing:
#  tensor([[-0.1401,  0.3750, -0.0378,  ...,  0.3886,  0.0538, -0.3736],
#          [ 0.0229,  0.1462,  0.1609,  ...,  0.0798,  0.1178,  0.0921],
#          [-0.2510, -0.2451, -0.1135,  ..., -0.1026, -0.1162,  0.0436],
#          ...,
#          [-0.0075,  0.1442,  0.0580,  ...,  0.0728, -0.3548,  0.0390],
#          [ 0.2500,  0.2988, -0.0007,  ...,  0.0599,  0.1179,  0.0142],
#          [-0.1440, -0.1390, -0.0077,  ..., -0.0503, -0.0603, -0.0880]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-1.8177e-04, -6.5491e-06,  7.8356e-05,  ...,  6.4899e-05,
#           1.0066e-04, -4.8942e-05], requires_grad=True),
#  Parameter containing:
#  tensor([0.2418, 3.6994, 0.0108,  ..., 0.1527, 0.1349, 0.1963],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.0045,  0.0422, -0.1379,  ..., -0.0134, -0.0081, -0.0027],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 2.0898e-02,  1.0362e-01, -1.4297e-01,  ...,  5.7716e-01,
#           -6.8225e-02, -7.5517e-01],
#          [-5.2834e-02, -1.6259e-01, -1.5620e-01,  ...,  3.2322e-01,
#            1.0325e-01, -5.2400e-02],
#          [ 2.1759e-01,  2.8451e-03, -9.2531e-02,  ...,  6.3748e-02,
#            6.4330e-01,  4.7813e-02],
#          ...,
#          [-3.6987e-04, -1.4032e-01, -7.7211e-02,  ...,  1.1889e-01,
#           -1.1440e-01,  3.1204e-01],
#          [-1.7644e-01, -1.7326e-01, -2.5905e-01,  ...,  3.5245e-01,
#           -3.7310e-01, -3.1811e-01],
#          [ 5.7680e-01,  1.2082e-01, -2.5147e-01,  ..., -7.9639e-02,
#            3.7004e-01,  4.7297e-01]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.0096, -0.0164, -0.0118,  ..., -0.0049, -0.0310, -0.0228],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.2383, -0.0654,  0.0977,  ...,  0.3969, -0.0710, -0.3679],
#          [ 0.0544,  0.1385,  0.0552,  ..., -0.0671,  0.2073, -0.2319],
#          [-0.1500,  0.0379, -0.0888,  ..., -0.0515,  0.1905,  0.3130],
#          ...,
#          [ 0.2497,  0.2651, -0.1447,  ..., -0.1583,  0.1495, -0.0563],
#          [-0.1567,  0.1205,  0.2073,  ...,  0.0860,  0.1207, -0.4017],
#          [ 0.1213, -0.4028,  0.0108,  ...,  0.2183,  0.1415, -0.0536]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-0.0469,  0.3393, -3.4478,  ...,  1.0659,  0.7656,  0.3649],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.3840,  1.7383,  0.0782,  ...,  0.2701,  0.2152, -0.4797],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.0534, -0.0239,  0.3816,  ..., -0.0913, -0.0424,  0.0489],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[-0.1763, -0.0240,  0.0489,  ...,  0.0094,  0.2232,  0.0532],
#          [ 0.2028, -0.2944, -0.1046,  ...,  0.0444, -0.1104, -0.0310],
#          [-0.2359,  0.1697, -0.0551,  ...,  0.2138,  0.0796,  0.0757],
#          ...,
#          [ 0.3132,  0.0936, -0.2513,  ..., -0.4153,  0.1896, -0.0804],
#          [-0.0051, -0.0918,  0.0982,  ...,  0.1492,  0.0879,  0.1387],
#          [-0.1009,  0.2259, -0.5959,  ..., -0.0064,  0.0405, -0.3945]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 3.6384e-08,  3.5984e-08,  4.1826e-08,  ..., -6.6696e-09,
#          -2.4974e-09,  5.4532e-09], requires_grad=True),
#  Parameter containing:
#  tensor([[-0.5277,  0.2092,  0.2869,  ..., -0.1848, -0.0365, -0.0983],
#          [-0.1675,  0.2431,  0.2624,  ...,  0.1030,  0.0575,  0.0212],
#          [ 0.2130, -0.0968,  0.0991,  ...,  0.0266,  0.0672,  0.1092],
#          ...,
#          [-0.0672, -0.1812,  0.0364,  ..., -0.2368,  0.0310,  0.0389],
#          [ 0.1814, -0.1029, -0.0326,  ..., -0.0469,  0.0746,  0.0172],
#          [-0.6669,  0.0513, -0.0920,  ...,  0.0841, -0.0536,  0.2916]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 4.9882e-05, -2.2069e-04, -8.9123e-05,  ..., -9.5420e-07,
#          -1.4541e-04, -1.2472e-04], requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.3269,  0.0759, -0.0737,  ..., -0.0036, -0.0216,  0.0878],
#          [-0.1032, -0.1963,  0.0108,  ..., -0.2815,  0.0474, -0.0799],
#          [ 0.0274,  0.0365, -0.0569,  ..., -0.0735,  0.3409, -0.3222],
#          ...,
#          [ 0.2050,  0.0024, -0.0908,  ...,  0.6984, -0.2150,  0.5525],
#          [-0.1496,  0.0435,  0.1150,  ...,  0.0516,  0.0505,  0.0899],
#          [ 0.0624,  0.0606, -0.1547,  ...,  0.4658, -0.0080, -0.0760]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-1.2389e-04,  1.0904e-04, -4.1303e-05,  ..., -6.1741e-05,
#           1.1545e-04,  9.7293e-05], requires_grad=True),
#  Parameter containing:
#  tensor([[-1.7114e-01,  2.3472e-01, -1.8568e-01,  ..., -2.3259e-01,
#           -1.1793e-01,  4.4444e-01],
#          [ 1.3568e-01,  1.3138e-01,  9.1258e-02,  ..., -2.7377e-01,
#            1.8412e-01,  3.0612e-02],
#          [-2.4136e-01,  4.0144e-02,  1.0511e-01,  ...,  2.4893e-01,
#            1.7515e-02, -6.4044e-01],
#          ...,
#          [-1.2718e-02,  3.4478e-01, -5.2243e-02,  ..., -8.9018e-02,
#           -1.1995e-01,  2.3701e-01],
#          [ 1.1985e-01,  4.3541e-02,  3.0207e-01,  ..., -2.1328e-01,
#           -1.2355e-01, -3.3348e-04],
#          [-2.5232e-01, -1.6868e-01,  1.6015e-01,  ..., -2.4853e-01,
#           -3.5861e-01,  2.3820e-01]], requires_grad=True),
#  Parameter containing:
#  tensor([-8.0036e-05,  1.1738e-04,  9.9016e-05,  ...,  5.5774e-05,
#           9.7310e-05, -3.4212e-05], requires_grad=True),
#  Parameter containing:
#  tensor([ 0.2472,  0.5950, -0.0084,  ...,  0.1442,  0.1253,  0.2221],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.0072,  0.0058, -0.0042,  ..., -0.0107, -0.0110, -0.0047],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[-0.0863,  0.0661, -0.0985,  ..., -0.0975, -0.0581,  0.1508],
#          [-0.0831,  0.0571, -0.1560,  ..., -0.1328, -0.0982,  0.3427],
#          [ 0.7054, -0.5352, -0.2343,  ...,  0.3858,  0.5721, -0.3282],
#          ...,
#          [ 0.4349,  0.0379, -0.2475,  ...,  0.5435, -0.6330, -0.0401],
#          [-0.4534, -0.1098, -0.2201,  ...,  0.2497, -0.0849,  0.6146],
#          [ 0.0993, -0.0710, -0.1250,  ..., -0.0157, -0.1292,  0.1961]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-0.0040, -0.0134, -0.0267,  ..., -0.0098, -0.0076, -0.0035],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[-0.0967,  0.2087, -0.3278,  ...,  0.1529,  0.1564,  0.8032],
#          [-0.0998,  0.2735,  0.2839,  ..., -0.0545, -0.0680,  0.1381],
#          [ 0.2716,  0.1659, -0.0314,  ..., -0.2265,  0.1875, -0.0113],
#          ...,
#          [ 0.0420,  0.1815,  0.1897,  ..., -0.0697, -0.3588,  0.2375],
#          [ 0.1390,  0.1847, -0.4290,  ...,  0.0338,  0.2664,  0.0648],
#          [-0.4639, -0.5262, -0.1255,  ..., -0.2033, -0.3165,  0.0657]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-0.1171,  0.3888, -6.3488,  ...,  1.5915,  1.5834,  0.3735],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0.4247, 1.1221, 0.0668,  ..., 0.3170, 0.2638, 0.5544],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.0682,  0.0433,  0.3427,  ..., -0.1314, -0.0894, -0.0515],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[-0.0388, -0.3647, -0.0461,  ..., -0.0033,  0.1416, -0.1583],
#          [-0.0026,  0.0681,  0.0882,  ..., -0.1301,  0.0181,  0.3695],
#          [-0.1454, -0.0024,  0.0492,  ...,  0.0717,  0.0758,  0.1798],
#          ...,
#          [-0.1629,  0.1396,  0.0487,  ..., -0.1109, -0.3510, -0.1032],
#          [-0.0554, -0.0289, -0.0724,  ..., -0.0342,  0.1619, -0.1879],
#          [ 0.1052,  0.0506, -0.1449,  ..., -0.0454,  0.2317, -0.0586]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 7.5954e-10,  3.0756e-08, -3.5328e-08,  ...,  1.3858e-08,
#          -1.8537e-08,  2.4769e-08], requires_grad=True),
#  Parameter containing:
#  tensor([[-0.0375, -0.4661,  0.0070,  ...,  0.0236, -0.3652,  0.2188],
#          [ 0.5726, -0.2249, -0.0106,  ..., -0.0451, -0.2127, -0.0318],
#          [-0.1111,  0.1433, -0.0673,  ...,  0.2169,  0.3970, -0.1283],
#          ...,
#          [ 0.1124,  0.1733, -0.0149,  ..., -0.0923,  0.1989, -0.1581],
#          [ 0.2999, -0.3443, -0.0311,  ...,  0.1169, -0.0016, -0.3632],
#          [-0.0453,  0.1054, -0.0088,  ..., -0.0537,  0.0594,  0.2359]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 1.5530e-04,  9.6933e-05,  2.8370e-05,  ..., -4.0322e-05,
#           1.1184e-04, -1.0156e-04], requires_grad=True),
#  Parameter containing:
#  tensor([[-0.1742,  0.0521,  0.0692,  ...,  0.0677,  0.2230,  0.2840],
#          [ 0.0087,  0.0330, -0.0251,  ..., -0.2524, -0.1337,  0.1433],
#          [-0.1303,  0.0621,  0.0314,  ..., -0.1934, -0.0034, -0.0015],
#          ...,
#          [ 0.2012, -0.0506,  0.1147,  ..., -0.0939, -0.4428, -0.1403],
#          [ 0.2998, -0.1412, -0.0882,  ..., -0.1633,  0.1650,  0.0571],
#          [-0.0141, -0.3531, -0.0089,  ..., -0.0178,  0.2449, -0.0601]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 2.0157e-04, -4.8850e-05,  5.8603e-05,  ..., -7.9340e-06,
#          -1.6100e-04, -2.0958e-04], requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.1897, -0.4058,  0.2459,  ...,  0.1060, -0.0061,  0.0539],
#          [ 0.5005,  0.1634,  0.1149,  ...,  0.3725, -0.1426, -0.1359],
#          [-0.1287,  0.0545, -0.0892,  ...,  0.9267, -0.2976, -0.5106],
#          ...,
#          [ 0.1455, -0.0845, -0.2447,  ..., -0.2113,  0.0793,  0.2636],
#          [ 0.2786,  0.3947, -0.3584,  ...,  0.1826, -0.2791, -0.0468],
#          [-0.2982,  0.1361,  0.1936,  ..., -0.0473,  0.4111,  0.0860]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-9.7850e-05,  5.6919e-05, -6.6342e-05,  ...,  1.0923e-04,
#           6.8324e-05,  1.1687e-04], requires_grad=True),
#  Parameter containing:
#  tensor([ 0.2618,  0.4551, -0.0016,  ...,  0.1519,  0.1556,  0.2171],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.0101,  0.0073, -0.0005,  ..., -0.0102, -0.0258, -0.0135],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[-0.2771,  0.0416, -0.1846,  ..., -0.2151, -0.2253,  0.0806],
#          [ 0.7400,  0.5102, -0.2148,  ..., -0.0354,  0.0445,  0.0316],
#          [-0.0954,  0.3624, -0.1632,  ...,  0.9356, -0.4125, -0.1493],
#          ...,
#          [-0.3512,  0.1466, -0.3590,  ...,  0.4160,  0.2370,  0.2730],
#          [-0.4621,  0.0740, -0.2118,  ...,  0.0237, -0.2179, -0.5262],
#          [ 0.5802,  0.3020, -0.0232,  ..., -0.1998,  0.0476,  0.1570]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-0.0124, -0.0227, -0.0205,  ..., -0.0160, -0.0147, -0.0013],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[-0.1877, -0.2368, -0.3330,  ...,  0.3556, -0.5309,  0.0589],
#          [ 0.1398, -0.1988, -0.0297,  ..., -0.4539, -0.1337, -0.0825],
#          [ 0.2453,  0.7997, -0.0841,  ...,  0.8760,  0.0587, -0.3599],
#          ...,
#          [-0.6733,  0.1006,  0.2587,  ...,  0.0940, -0.0121,  0.0638],
#          [ 0.1161,  0.4260, -0.0233,  ..., -0.6908, -0.1812, -0.3575],
#          [-0.0470, -0.4129,  0.2001,  ..., -0.0820,  0.0675,  0.1984]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-0.0532,  0.8813, -9.5014,  ...,  2.1252,  2.2293,  1.5949],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0.4613, 0.9553, 0.0414,  ..., 0.3782, 0.2947, 0.6072],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.0867,  0.0138,  0.3736,  ..., -0.1550, -0.1255, -0.0864],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[-0.3222,  0.1335, -0.1932,  ..., -0.0759, -0.0178, -0.0799],
#          [ 0.0809, -0.3401, -0.1913,  ..., -0.0781,  0.1207, -0.3123],
#          [-0.1393, -0.0228, -0.1115,  ..., -0.0061, -0.2275,  0.1875],
#          ...,
#          [ 0.0746,  0.1180,  0.2670,  ..., -0.2919,  0.1434, -0.3992],
#          [-0.1159, -0.1494, -0.4719,  ..., -0.2194, -0.0302, -0.2479],
#          [ 0.0650,  0.0989,  0.2289,  ..., -0.0609,  0.0281,  0.3335]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-2.1717e-08,  1.0430e-08, -2.3503e-09,  ...,  1.3796e-09,
#          -2.6105e-08, -6.6164e-09], requires_grad=True),
#  Parameter containing:
#  tensor([[-0.3173,  0.0207,  0.0505,  ...,  0.1553,  0.1948, -0.1665],
#          [-0.2783,  0.0966, -0.0284,  ...,  0.1884, -0.1972,  0.1900],
#          [-0.0583,  0.8948, -0.1484,  ...,  1.0143,  0.0926, -0.4652],
#          ...,
#          [-0.1631,  0.0424,  0.0307,  ..., -0.3215,  0.0636, -0.7936],
#          [-0.2198, -0.1135,  0.0019,  ...,  0.1782,  0.1527, -0.2194],
#          [ 0.3259,  0.4030,  0.1801,  ..., -0.1705,  0.3344, -0.1189]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-4.7632e-05,  1.7358e-06, -6.5649e-05,  ...,  5.4411e-05,
#           4.0806e-05, -9.6019e-05], requires_grad=True),
#  Parameter containing:
#  tensor([[-0.3628,  0.0928, -0.1512,  ...,  0.1452,  0.1180, -0.0830],
#          [-0.5417,  0.1464,  0.1044,  ..., -0.0500, -0.0095, -0.2436],
#          [-0.0096, -0.3820, -0.1445,  ...,  0.1243,  0.2263,  0.0249],
#          ...,
#          [-0.1645,  0.1078,  0.1321,  ...,  0.0611,  0.0721, -0.4235],
#          [ 0.1343, -0.1134, -0.2018,  ..., -0.1399, -0.1114,  0.1498],
#          [ 0.0960, -0.1872,  0.1181,  ...,  0.3894,  0.1529,  0.0147]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 2.1044e-04, -7.0528e-05,  4.4847e-05,  ..., -1.0231e-04,
#           5.6939e-06,  8.2211e-05], requires_grad=True),
#  Parameter containing:
#  tensor([[-4.2486e-03, -5.6567e-02,  3.7509e-02,  ...,  2.4142e-01,
#            3.1008e-01, -2.9485e-01],
#          [-2.0313e-01,  2.1222e-01,  5.8495e-01,  ..., -1.5624e-01,
#           -2.8444e-01, -5.7021e-01],
#          [ 4.4037e-02, -7.0089e-01, -5.1020e-04,  ...,  1.8915e-01,
#            2.0014e-01, -8.7091e-02],
#          ...,
#          [-4.1879e-01, -3.6362e-01,  3.6552e-02,  ...,  2.5507e-01,
#            7.0399e-02, -7.7559e-02],
#          [-4.7550e-02, -2.3429e-01, -1.2745e-01,  ..., -1.1868e-02,
#           -1.1984e-01, -1.3000e-01],
#          [ 1.7805e-01,  3.5467e-01,  4.4246e-02,  ...,  8.4653e-01,
#            1.3344e-01,  1.0353e-01]], requires_grad=True),
#  Parameter containing:
#  tensor([-1.3088e-04, -2.8431e-06,  5.0185e-05,  ...,  6.7402e-05,
#           5.6175e-05, -3.4183e-05], requires_grad=True),
#  Parameter containing:
#  tensor([0.2475, 0.3837, 0.0166,  ..., 0.1410, 0.1598, 0.2116],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.
],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 3.8895e-05, -1.4398e-04,  2.0009e-05,  ...,  1.4059e-04,
#           1.1176e-04, -6.5044e-06], requires_grad=True),
#  Parameter containing:
#  tensor([[-0.1826,  0.0419, -0.2398,  ..., -0.0150, -0.3415, -0.1298],
#          [-0.0513, -0.1444, -0.0631,  ...,  0.1238,  0.1397,  0.1156],
#          [ 0.0678,  0.1952, -0.1720,  ..., -0.2982, -0.0275, -0.0643],
#          ...,
#          [-0.4323, -0.1562,  0.2272,  ...,  0.1991, -0.2985,  0.2188],
#          [-0.2234,  0.0216,  0.3908,  ...,  0.5795, -0.1124, -0.0977],
#          [ 0.1319,  0.2616, -0.1045,  ...,  0.1926,  0.4533,  0.0502]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-1.3494e-04,  9.4219e-05,  7.6599e-05,  ..., -1.3594e-04,
#           5.0890e-05,  1.5650e-04], requires_grad=True),
#  Parameter containing:
#  tensor([[-0.0376,  0.2316, -0.3920,  ...,  0.5837, -0.1765, -0.5645],
#          [-0.4411, -0.1476,  0.2105,  ..., -0.5783,  0.5121,  0.7316],
#          [-1.7680,  0.5040, -0.2035,  ..., -0.8968,  2.0592,  0.6151],
#          ...,
#          [-0.1165,  0.1104,  0.4588,  ..., -0.0493,  0.3583,  0.1064],
#          [ 0.3172,  0.1234, -0.4913,  ..., -0.2769, -0.0780,  0.0576],
#          [-0.3786, -0.3959,  0.4174,  ...,  0.1631,  0.2252,  0.2241]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-5.5455e-05,  7.8677e-05, -9.1555e-05,  ...,  3.9931e-05,
#           8.5833e-05, -8.9854e-05], requires_grad=True),
#  Parameter containing:
#  tensor([0.2302, 0.2987, 0.0246,  ..., 0.1493, 0.1654, 0.1794],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.0125,  0.0046, -0.1829,  ..., -0.0065, -0.0155, -0.0112],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 4.2127e-01,  1.4187e-01, -2.3716e-01,  ..., -4.3347e-01,
#            6.7476e-01,  7.6247e-02],
#          [-1.6129e-01, -1.6901e-01, -2.9774e-01,  ..., -9.5575e-01,
#           -1.7980e-01,  3.3025e-01],
#          [ 2.2390e-01,  1.7718e-02, -1.9269e-01,  ..., -3.0175e-01,
#            4.8217e-01,  5.5951e-01],
#          ...,
#          [-2.5657e-02,  2.6155e-01, -4.4842e-02,  ...,  4.2067e-01,
#            2.2811e-01,  1.2517e-01],
#          [-1.5133e-01, -7.2474e-01, -1.3365e-01,  ...,  5.1478e-01,
#           -5.0685e-01,  1.8145e-01],
#          [ 4.0389e-01, -2.1580e-04, -4.4708e-01,  ...,  1.6914e-01,
#           -2.3493e-01, -2.7164e-01]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.0396, -0.0559, -0.0484,  ..., -0.0101, -0.0065, -0.0448],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 1.0647, -0.0251, -0.0411,  ..., -0.0093,  0.5250, -0.3269],
#          [-0.1241,  0.0087, -0.0303,  ...,  0.2042,  0.4986, -0.5865],
#          [ 1.4659, -0.2331,  0.4136,  ...,  0.2513,  0.5503,  0.1387],
#          ...,
#          [-0.7368, -0.2020, -0.2391,  ...,  0.6417, -0.1735,  0.1169],
#          [-0.1581, -0.3664,  0.2736,  ..., -0.1960,  0.3624,  0.9082],
#          [-0.7598,  0.2349, -0.3522,  ..., -0.1044,  0.1324, -0.5332]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([  0.1365,  -1.6378, -17.8942,  ...,   1.3208,   2.6137,   2.1328],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0.5704, 0.8814, 0.0031,  ..., 0.4986, 0.4329, 0.6875],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.0621,  0.0621,  0.9261,  ..., -0.1222, -0.1709, -0.1094],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.0982, -0.1111, -0.2061,  ...,  0.2087,  0.1355,  0.1631],
#          [-0.0575,  0.2637,  0.1002,  ...,  0.4082, -0.0924,  0.2032],
#          [ 0.0308, -0.2495, -0.2887,  ..., -0.0592, -0.0816, -0.1220],
#          ...,
#          [-0.2743, -0.2825, -0.1117,  ...,  0.1980, -0.1297,  0.1816],
#          [ 0.1332,  0.1151, -0.2274,  ..., -0.4542, -0.4051, -0.0296],
#          [-0.3262, -0.3375, -0.3775,  ...,  0.2651,  0.1302,  0.2727]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 2.3975e-08,  4.5888e-11, -3.3337e-08,  ..., -3.3597e-09,
#           4.8740e-09, -6.4201e-09], requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.9613, -0.1577, -0.3749,  ...,  0.1584, -0.0871, -0.3812],
#          [ 0.6253,  0.0052, -0.0989,  ...,  0.4989, -0.6038, -0.0205],
#          [-0.0778,  0.3199,  0.3866,  ..., -0.0699,  0.6434, -0.3482],
#          ...,
#          [ 0.2847,  0.2873,  0.1282,  ..., -0.2368,  0.0715, -0.0265],
#          [ 0.6989, -0.5973,  0.3635,  ...,  0.4998,  0.7465,  0.1512],
#          [-0.1643,  0.2597, -0.1401,  ..., -0.3205,  0.0960,  0.2076]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 1.1537e-04,  4.3441e-05, -4.3625e-05,  ..., -7.7073e-05,
#          -3.4948e-05, -2.0244e-04], requires_grad=True),
#  Parameter containing:
#  tensor([[-0.0384, -0.2353,  0.0110,  ..., -0.0941,  0.1147, -0.3188],
#          [-0.2108, -0.0368,  0.0009,  ..., -0.0473, -0.0657, -0.5584],
#          [ 0.1396, -0.1527, -0.2983,  ...,  0.6937, -0.0869,  0.3989],
#          ...,
#          [ 0.0795, -0.0816, -0.0667,  ..., -0.0595,  0.2772, -0.0758],
#          [-0.0042, -0.1621, -0.1130,  ..., -0.2027, -0.3615,  0.1100],
#          [ 0.0374, -0.0652, -0.3777,  ...,  0.2121,  0.0522,  0.2324]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-1.3816e-04, -4.0785e-05, -8.5291e-05,  ..., -1.6815e-04,
#           1.4683e-04, -6.9241e-05], requires_grad=True),
#  Parameter containing:
#  tensor([[-0.8867, -0.9824,  0.0899,  ...,  0.2672, -0.8210,  0.2834],
#          [ 0.6426,  1.0378, -0.6894,  ..., -0.7055,  0.2015,  0.2301],
#          [ 1.0528,  1.9338, -2.0764,  ...,  0.4980, -1.0942,  0.2554],
#          ...,
#          [-0.0965, -0.9521, -0.0321,  ..., -0.4139, -0.4147,  0.8086],
#          [ 0.0596,  0.4884, -0.4703,  ...,  0.2499, -0.4029, -0.4083],
#          [-0.2949, -0.0214, -0.2061,  ..., -0.2948, -0.1682,  0.0888]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([
],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 9.9868e-09, -1.1454e-08,  1.7821e-08,  ..., -1.2609e-08,
#          -1.5245e-08,  1.4790e-08], requires_grad=True),
#  Parameter containing:
#  tensor([[-8.4956e-01,  1.5918e-01, -1.8526e-01,  ...,  6.7878e-02,
#           -4.9173e-01, -7.6421e-02],
#          [ 1.6903e-01,  1.3576e-01, -1.2122e-01,  ...,  8.8441e-01,
#            1.0725e-03, -5.9953e-01],
#          [ 5.5373e-01,  9.4675e-01,  8.1946e-02,  ...,  2.0268e-01,
#           -2.5456e-01,  6.4486e-03],
#          ...,
#          [-6.7097e-01,  2.1322e-01, -1.1625e-01,  ...,  4.9249e-01,
#           -1.1612e+00, -2.0584e-01],
#          [-6.6258e-01,  2.3626e-01,  3.2926e-01,  ...,  3.3694e-01,
#           -2.5813e-01,  1.1668e-01],
#          [ 2.5630e-01, -1.5091e+00,  1.9580e-01,  ..., -3.8004e-01,
#            7.0942e-01, -6.0572e-01]], requires_grad=True),
#  Parameter containing:
#  tensor([-8.0631e-07,  6.7443e-05, -1.5577e-04,  ...,  2.6021e-04,
#           6.1794e-05,  1.2565e-04], requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.2422,  0.0118, -0.2530,  ..., -0.2158,  0.1832, -0.6826],
#          [-0.0843, -0.1935,  0.2492,  ...,  0.1291,  0.2978,  0.0082],
#          [ 0.2305,  0.0428, -0.1331,  ...,  0.0545, -0.1174,  0.4556],
#          ...,
#          [ 0.2027,  0.0979,  0.3087,  ..., -0.0177,  0.0223, -0.3193],
#          [-0.2982, -0.0170, -0.0799,  ...,  0.2167, -0.1630,  0.2663],
#          [-0.2511,  0.4323, -0.1648,  ..., -0.3213,  0.1506, -0.0883]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 6.3603e-05,  8.8822e-06, -5.0038e-05,  ...,  5.5261e-05,
#           1.2705e-04,  1.1313e-04], requires_grad=True),
#  Parameter containing:
#  tensor([[-0.5907,  0.4790, -0.7384,  ...,  1.1745,  0.8924, -0.8085],
#          [-0.1549,  0.2107, -0.3133,  ..., -0.7919,  0.8802,  1.8446],
#          [-0.4284, -0.9653,  1.6367,  ..., -2.0053, -3.3991,  1.0922],
#          ...,
#          [-0.4489, -0.0801,  0.6046,  ..., -0.8317,  0.0448, -0.3814],
#          [-0.1697, -0.3396,  0.4382,  ..., -0.1754,  0.0575,  0.3501],
#          [-0.3067,  0.7273,  0.3374,  ...,  0.2490, -1.0700,  0.7745]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([6.6038e-05, 1.3481e-05, 9.5520e-05,  ..., 4.8783e-06, 3.4314e-05,
#          6.6734e-05], requires_grad=True),
#  Parameter containing:
#  tensor([0.1749, 0.1973, 0.0366,  ..., 0.1237, 0.1376, 0.1468],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.0055,  0.0006, -0.2534,  ...,  0.0045, -0.0063, -0.0062],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.1306, -0.1231, -0.2624,  ...,  0.8589,  0.6363,  0.2348],
#          [ 0.2749, -0.5528, -0.6487,  ..., -0.6019, -1.4530,  0.5414],
#          [ 0.3737, -0.1926, -0.5685,  ..., -0.8278, -0.2861,  0.2325],
#          ...,
#          [-0.1210,  0.4439, -0.5178,  ...,  0.2568, -0.6122,  0.5249],
#          [ 0.0832, -0.3460, -0.7300,  ..., -0.2045,  0.2767, -0.0364],
#          [-0.4805, -0.2447, -0.4632,  ...,  0.2596,  0.6610, -0.0066]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-0.0370, -0.1687,  0.0611,  ..., -0.0946, -0.2699, -0.1663],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[-0.3945,  0.2685, -0.2323,  ...,  0.0271, -0.0702,  0.1142],
#          [ 0.4076, -0.3351,  0.3034,  ..., -0.1906, -1.1046, -0.4701],
#          [ 2.1833,  0.7186,  0.3129,  ...,  0.0073,  2.4374,  2.1195],
#          ...,
#          [ 0.1475, -0.9522, -0.4178,  ..., -0.1460,  0.5097, -0.7961],
#          [ 0.2510,  0.1730, -0.3383,  ..., -0.5465, -0.6428, -0.1646],
#          [-0.2727,  0.6968, -0.0599,  ...,  0.6691, -0.9816, -0.7700]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ -0.8399,  -0.8917, -23.9213,  ...,   0.7011,   1.5573,   3.7160],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.6162,  0.7545, -0.2216,  ...,  0.5700,  0.5578,  0.6578],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.1535, -0.0143,  2.2452,  ..., -0.0358, -0.0883, -0.1256],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.4120,  0.1627, -0.1964,  ..., -0.5752, -0.5860,  0.0750],
#          [-0.2556, -0.0061, -0.1578,  ...,  0.0882, -0.0416, -0.5637],
#          [-0.2675,  0.0794, -0.2768,  ...,  0.0504, -0.0243, -0.3965],
#          ...,
#          [-0.1534,  0.1411,  0.3803,  ...,  0.0955, -0.1235,  0.1312],
#          [ 0.2263,  0.3589, -0.0048,  ...,  0.2224, -0.2478, -0.2285],
#          [-0.0941,  0.0784,  0.0852,  ..., -0.6553, -0.1332, -0.1262]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-1.8719e-08,  1.0677e-10, -6.5735e-09,  ..., -6.1924e-09,
#          -9.0749e-09,  2.5046e-09], requires_grad=True),
#  Parameter containing:
#  tensor([[-0.1835,  0.4155,  0.2639,  ..., -0.1456, -0.6347,  0.0565],
#          [-0.2927,  0.6345, -0.0172,  ..., -1.0573,  0.3730,  0.1353],
#          [ 0.1067, -0.2847,  0.1338,  ...,  1.3769, -0.2456, -0.4191],
#          ...,
#          [-0.0250, -0.0713, -0.0784,  ..., -0.0024, -0.3034,  0.1492],
#          [-0.1525,  0.4687,  0.1935,  ...,  0.6110,  0.0650,  0.8054],
#          [-0.6323,  0.1946, -0.0883,  ..., -0.3761, -0.8231,  0.9750]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 7.4964e-05, -4.8851e-05,  5.3788e-05,  ..., -6.0132e-05,
#           7.8995e-05,  6.1886e-06], requires_grad=True),
#  Parameter containing:
#  tensor([[ 2.7456e-01, -2.5097e-01, -1.6449e-01,  ...,  8.1937e-02,
#           -3.2757e-04,  2.4179e-01],
#          [-1.2988e-01,  1.4794e-01, -1.7861e-02,  ...,  1.6992e-02,
#           -3.3075e-01,  1.2379e-01],
#          [ 1.7509e-02, -6.7896e-02,  1.1377e-01,  ..., -2.6919e-01,
#           -5.4466e-02,  4.8154e-01],
#          ...,
#          [ 1.1692e-01, -1.1259e-01,  3.5324e-01,  ...,  3.2266e-02,
#            2.8824e-03, -7.3328e-02],
#          [ 9.0631e-02,  7.3372e-02,  1.5047e-01,  ..., -1.2932e-01,
#           -8.5091e-02,  5.2401e-02],
#          [ 6.8565e-02, -2.4956e-01, -6.8424e-02,  ...,  9.3908e-02,
#            2.7398e-01,  8.5115e-02]], requires_grad=True),
#  Parameter containing:
#  tensor([ 1.5081e-04, -7.1966e-05, -1.0628e-04,  ..., -1.5112e-06,
#          -9.7656e-05,  2.0047e-06], requires_grad=True),
#  Parameter containing:
#  tensor([[-1.0380,  0.2649, -0.0248,  ..., -1.2465,  0.1856, -0.0966],
#          [-0.9699,  0.0973, -0.7568,  ...,  0.5988,  0.1026, -0.2694],
#          [-1.1867,  2.3857, -1.6927,  ..., -1.1056,  0.5446, -2.8438],
#          ...,
#          [ 0.3390, -0.7853, -0.6248,  ..., -0.3395, -0.1695, -0.5595],
#          [ 0.0616,  0.3881,  0.6518,  ...,  0.3586,  0.0893,  0.1425],
#          [ 0.2627, -1.2482,  0.3841,  ..., -0.5118,  0.5610,  1.9412]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 2.5691e-05,  1.4792e-05,  4.5116e-05,  ..., -3.6785e-05,
#           4.4072e-05, -2.2314e-05], requires_grad=True),
#  Parameter containing:
#  tensor([0.1702, 0.1765, 0.0361,  ..., 0.1230, 0.1430, 0.1411],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.0055, -0.0020, -0.2617,  ...,  0.0018, -0.0071, -0.0058],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.5149, -0.5217, -0.6863,  ..., -0.1283, -0.4189,  0.1364],
#          [ 0.2112,  0.1196, -0.0589,  ..., -0.0295, -0.2493,  0.1270],
#          [ 0.3269, -0.7380, -0.5900,  ...,  0.2238, -0.1109, -0.1669],
#          ...,
#          [-0.0774,  0.3431, -0.2272,  ...,  0.3581,  0.1046,  0.5497],
#          [-0.9051, -0.2050, -0.7772,  ..., -0.0561,  0.6092,  0.6164],
#          [-0.4633,  0.2144, -0.1491,  ..., -0.2729,  0.3225, -0.2008]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-0.0129, -0.0056, -0.1138,  ..., -0.0219, -0.1147, -0.0146],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[-0.5277, -0.2208,  0.6602,  ..., -0.1141, -0.1716,  0.1357],
#          [-0.0487, -0.1120, -2.2656,  ...,  0.4222,  0.3526, -0.5336],
#          [-0.4109, -1.0156,  0.9441,  ...,  2.3428,  0.2631, -0.1558],
#          ...,
#          [ 0.4299,  0.0550, -0.5391,  ..., -0.1822,  0.0044, -0.2853],
#          [-0.9738,  0.0321,  0.1500,  ...,  0.1499,  0.5045, -0.4653],
#          [ 0.2586, -0.1465, -0.7029,  ...,  0.5936,  0.2466,  0.3701]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ -1.2000,  -1.1836, -14.3285,  ...,   0.6703,   1.4801,   4.1020],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.7046,  0.8045, -0.3600,  ...,  0.6719,  0.6493,  0.7444],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.1295,  0.0104,  3.5315,  ..., -0.0080, -0.1255, -0.0585],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[-0.1226,  0.0268, -0.1442,  ...,  0.1731,  0.6311, -0.2536],
#          [-0.0250, -0.2581, -0.2451,  ..., -0.2824,  0.2424,  0.3324],
#          [ 0.3288, -0.0109,  0.2350,  ..., -0.5203,  0.0943, -0.1825],
#          ...,
#          [ 0.5210, -0.3353,  0.0407,  ..., -0.1085,  0.3561,  0.1601],
#          [ 0.2936,  0.2039,  0.2988,  ..., -0.2115, -0.2366, -0.0126],
#          [-0.0434,  0.2213, -0.3463,  ...,  0.1789, -0.2006,  0.0284]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-1.5945e-09,  1.5585e-08,  6.9334e-09,  ...,  1.4479e-08,
#           4.2597e-09, -9.9999e-09], requires_grad=True),
#  Parameter containing:
#  tensor([[ 3.6644e-01, -5.5053e-01,  1.3579e-01,  ..., -7.4933e-01,
#            1.6379e-02,  4.5125e-01],
#          [-1.7156e-01, -1.5428e-01,  5.2010e-02,  ...,  8.6630e-01,
#           -2.9836e-01,  3.2325e-02],
#          [ 5.6322e-01,  4.5952e-01, -6.3268e-02,  ..., -9.7739e-01,
#            8.0174e-01, -3.0821e-01],
#          ...,
#          [ 3.9526e-01, -2.6628e-01,  2.8981e-01,  ..., -5.5374e-01,
#           -2.8830e-01, -1.5812e-01],
#          [-1.1223e-01,  2.3827e-01,  6.5591e-04,  ...,  1.0150e+00,
#            5.6667e-01, -4.0513e-01],
#          [ 3.1049e-01, -9.1015e-01, -1.7089e-01,  ...,  5.0647e-01,
#           -1.7852e-01, -9.2401e-01]], requires_grad=True),
#  Parameter containing:
# ...
#          ...,
#          [ 0.2659, -1.2432,  0.9923,  ...,  0.7083,  0.3932,  0.0358],
#          [ 0.6407, -0.7284,  0.1575,  ...,  0.3115, -0.4485,  0.2952],
#          [ 0.1978,  0.3929, -1.6379,  ...,  1.9093, -0.9600,  1.2508]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0., 0., 0.,  ..., 0., 0., 0.], requires_grad=True),
#  Parameter containing:
#  tensor([0.0704, 0.0865, 0.0741,  ..., 0.0937, 0.0691, 0.0596],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.0123,  0.0144, -0.0125,  ...,  0.0045,  0.0026, -0.0011],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.4870,  0.1904,  0.0826,  ...,  0.2168,  0.1098, -0.1266],
#          [-0.0436, -0.2525,  0.2865,  ...,  0.3993,  0.4737,  0.2958],
#          [ 1.2146,  0.5358, -0.0367,  ...,  0.0501,  0.0593, -0.3458],
#          ...,
#          [-0.1313, -0.2964, -0.6765,  ...,  0.7214,  0.0722,  0.1747],
#          [-0.0231,  0.0925, -0.1640,  ...,  0.3327, -0.1718, -0.6773],
#          [ 0.3307,  0.1789, -0.1768,  ...,  0.1262, -0.3805,  0.5807]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.0110, -0.1361, -0.0931,  ..., -0.1756, -0.1673,  0.2903],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[-0.0841, -0.0351,  0.1444,  ..., -0.1039,  0.5350,  0.1118],
#          [ 0.2062,  0.6042,  0.6566,  ..., -0.3616, -0.2929, -0.7799],
#          [-0.2750,  0.0404,  0.1537,  ..., -0.2560,  1.1713,  0.0680],
#          ...,
#          [-0.3446, -0.6904,  0.1422,  ..., -0.2942,  0.4681,  0.0156],
#          [-0.2585,  0.4181, -0.5347,  ..., -0.5107,  0.4917,  0.3440],
#          [-1.3676, -0.3749,  0.1708,  ..., -0.1886,  0.6621, -0.2120]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 7.0714, 26.6171, -3.3101,  ..., -2.8313,  1.7839, -0.4099],
#         requires_grad=True),
#  Parameter containing:
#  tensor([2.0166, 2.5804, 2.4358,  ..., 2.3498, 1.9589, 1.8662],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.2253, -0.3404, -0.1114,  ...,  0.1423,  0.0664,  0.2702],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 0
ires_grad=True),
#  Parameter containing:
#  tensor([0., 0., 0.,  ..., 0., 0., 0.], requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.3329,  0.5837,  0.3042,  ...,  0.5731, -0.3131, -0.6383],
#          [ 0.0345,  0.2805,  0.5561,  ..., -0.0295,  0.3486, -0.4338],
#          [ 0.0701, -0.3566, -0.5681,  ...,  0.2336,  0.1542,  0.1600],
#          ...,
#          [ 0.4651, -0.2960, -0.2881,  ...,  0.4515, -0.2615, -0.7236],
#          [-0.2676,  0.5308,  0.0864,  ...,  0.1758,  0.2891,  0.3623],
#          [-0.2251, -0.0216,  0.2107,  ...,  0.4160, -0.1383, -0.2045]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0., 0., 0.,  ..., 0., 0., 0.], requires_grad=True),
#  Parameter containing:
#  tensor([[-1.1533, -3.7431,  0.1348,  ..., -1.5508, -1.4358, -2.2813],
#          [-0.0743, -2.1517,  1.5458,  ...,  1.4523,  0.7106, -1.6589],
#          [ 0.9844,  0.7965, -0.4177,  ..., -1.4853,  1.4822,  0.6060],
#          ...,
#          [ 0.5388,  0.4843,  0.7056,  ...,  3.6437, -0.8075,  2.2838],
#          [ 0.7692, -0.1662, -1.2242,  ..., -1.3115,  0.7466,  0.9094],
#          [ 0.5786, -0.5242,  0.2671,  ..., -0.4478,  1.8604, -2.0082]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0., 0., 0.,  ..., 0., 0., 0.], requires_grad=True),
#  Parameter containing:
#  tensor([0.1090, 0.1479, 0.1417,  ..., 0.1308, 0.1169, 0.1070],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.0146,  0.0240, -0.0250,  ...,  0.0041, -0.0022,  0.0084],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[-0.0657, -0.1021, -0.1870,  ..., -0.2491,  0.0076, -0.0915],
#          [-0.1960,  0.5869,  0.2940,  ...,  0.2303,  0.5360,  0.2635],
#          [ 0.4442,  0.1450, -0.0410,  ...,  0.5436,  0.1522, -0.1761],
#          ...,
#          [-0.3562,  0.6053, -0.0583,  ...,  0.1712,  0.7084, -0.1664],
#          [-0.2651,  0.0874, -0.3879,  ..., -0.1228, -0.1827, -0.1020],
#          [ 0.5630,  0.3167, -0.2825,  ...,  0.4979,  0.8949,  0.0186]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-0.1049, -0.1545,  0.0542,  ..., -0.1007, -0.1250, -0.1733],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.4769, -0.1464, -0.1213,  ..., -1.2512, -0.0170, -0.8545],
#          [-0.2054, -0.2086, -0.5660,  ...,  0.1618, -1.0096, -0.5971],
#          [ 0.2334,  0.4658,  0.6119,  ..., -0.1296,  0.5379,  0.2784],
#          ...,
#          [ 0.3971,  0.0719, -0.7587,  ...,  0.4647,  0.0027, -0.1801],
#          [ 0.1276, -1.4004,  0.2391,  ..., -0.2516, -0.5597,  0.4276],
#          [ 0.8485,  1.5289,  1.4495,  ...,  0.4643, -0.2355,  1.1941]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 8.8727,  0.9144, -3.8595,  ..., -3.8726,  5.1243, -1.7396],
#         requires_grad=True),
#  Parameter containing:
#  tensor([2.3627, 2.3567, 3.4158,  ..., 2.6533, 2.0097, 1.9100],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.2370, -0.0524, -0.0506,  ...,  0.2956,  0.0612,  0.1440],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[-0.3936, -0.0731,  0.3345,  ...,  0.1406,  0.2499,  0.1561],
#          [-0.1510,  0.2031, -0.2209,  ..., -0.4725,  0.3397,  0.2059],
#          [-0.8021,  0.5504,  0.3260,  ..., -0.0027,  0.3528, -0.0807],
#          ...,
#          [ 0.2970, -0.1051,  0.1785,  ...,  0.1140, -0.4582, -0.0423],
#          [-0.0645,  0.1702,  0.0860,  ...,  0.2035, -0.2423, -0.8596],
#          [ 0.4168, -0.2558, -0.1861,  ...,  0.1651, -0.5461, -0.1635]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0., 0., 0.,  ..., 0., 0., 0.], requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.9420, -0.1656,  0.3363,  ...,  1.4995,  0.7112, -0.8928],
#          [-0.5953, -1.0322,  0.5752,  ...,  0.5418,  0.2084,  1.4472],
#          [-0.3183,  0.5891,  0.2225,  ...,  0.0684, -0.1978,  0.6504],
#          ...,
#          [-0.0166, -0.4765, -0.2015,  ..., -0.4694, -0.5755,  0.5608],
#          [ 0.0611,  1.4125, -0.2768,  ...,  0.5872, -0.3941,  0.1108],
#          [ 0.2543,  1.2954, -0.4028,  ...,  0.4838, -0.4755, -0.0371]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0., 0., 0.,  ..., 0., 0., 0.], requires_grad=True),
#  Parameter containing:
#  tensor([[-0.0268, -0.0871,  0.2457,  ...,  0.2154,  0.2834,  0.2855],
#          [-0.4896, -0.0296,  0.0222,  ..., -0.4203,  0.2038,  0.3165],
#          [-0.0138,  0.4773,  0.0118,  ..., -0.0331,  0.5097,  0.2942],
#          ...,
#          [ 0.1239,  0.0960,  0.0952,  ..., -0.0519, -0.0721, -0.3150],
#          [-0.3938, -0.2183,  0.1597,  ...,  0.3119,  0.1139,  0.2273],
#          [-0.1993, -0.2126, -0.1006,  ...,  0.0408, -0.4925, -0.1435]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0., 0., 0.,  ..., 0., 0., 0.], requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.5923, -2.4814, -0.3552,  ...,  0.7025, -0.0513, -1.2935],
#          [ 1.6374,  0.0298, -0.4502,  ..., -2.9559,  0.3588, -0.1292],
#          [-0.3917,  0.4843,  0.6568,  ..., -0.6920, -0.9931,  0.2577],
#          ...,
#          [-0.5326, -0.8700, -0.0687,  ..., -0.7609,  0.2639,  0.6793],
#          [ 0.8172, -2.2064,  3.1659,  ..., -3.0032,  0.4378, -0.0151],
#          [ 0.2213,  0.9553, -0.6981,  ...,  1.1347, -1.2791,  0.8692]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0., 0., 0.,  ..., 0., 0., 0.], requires_grad=True),
#  Parameter containing:
#  tensor([0.3009, 0.4412, 0.4839,  ..., 0.3560, 0.2916, 0.2998],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.0359,  0.0691, -0.0250,  ...,  0.0340,  0.0192,  0.0342],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[-0.2008,  0.3029, -0.1681,  ..., -0.3103,  0.2686, -0.3648],
#          [-0.1795,  0.3647,  0.3111,  ...,  0.3376,  0.2206, -0.1197],
#          [-0.0208,  0.1745, -0.0395,  ..., -0.0548,  0.1859,  0.2524],
#          ...,
#          [-0.1303,  0.1855, -0.0225,  ..., -0.2580, -0.2374,  0.2547],
#          [ 0.1778, -0.0120, -0.2817,  ..., -0.0254,  0.3975, -0.2271],
#          [-0.1184,  0.0708, -0.0052,  ...,  0.0531,  0.2432, -0.1448]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0., 0., 0.,  ..., 0., 0., 0.], requires_grad=True),
#  Parameter containing:
#  tensor([[ 7.0478e-01,  1.2035e+00,  1.6801e-03,  ..., -1.1477e+00,
#           -1.0474e+00, -1.1137e+00],
#          [-6.1910e-01, -1.2887e-01,  1.1391e-01,  ...,  1.1155e+00,
#            1.2555e-01, -3.4689e-01],
#          [ 8.7366e-02,  1.0831e+00, -1.9236e-01,  ..., -2.5184e+00,
#           -3.8907e-01, -1.6964e+00],
#          ...,
#          [-3.9832e-01,  1.7425e+00,  5.4961e-02,  ..., -8.0180e-01,
#            9.6579e-01, -1.4693e+00],
#          [ 2.7033e-01, -3.3147e+00, -1.4122e-01,  ...,  1.2606e+00,
#           -2.0324e+00,  8.4854e-01],
#          [ 8.8670e-01,  2.4110e+00,  2.1947e-01,  ..., -5.7948e-01,
#           -1.3777e+00,  1.1684e+00]], requires_grad=True),
#  Parameter containing:
#  tensor([0., 0., 0.,  ..., 0., 0., 0.], requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.1972,  0.1435,  0.0082,  ..., -0.2408, -0.0392,  0.0582],
#          [ 0.2677, -0.0673, -0.2307,  ..., -0.1704,  0.0530,  0.4382],
#          [-0.3917, -0.2373,  0.0285,  ..., -0.0133,  0.2416, -0.1579],
#          ...,
#          [-0.3699,  0.0964, -0.2547,  ..., -0.5813, -0.3757, -0.0206],
#          [-0.0760, -0.1535,  0.0570,  ..., -0.2877, -0.0943,  0.0214],
#          [-0.1716,  0.0457,  0.1520,  ...,  0.0770, -0.7845,  0.0439]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0., 0., 0.,  ..., 0., 0., 0.], requires_grad=True),
#  Parameter containing:
#  tensor([[ 5.4802e-01,  1.7682e+00,  2.2793e+00,  ...,  1.2548e+00,
#            4.6002e-01,  8.8874e-01],
#          [-7.5110e-01, -2.5969e-01, -9.1595e-01,  ...,  1.1717e+00,
#           -7.0235e-01, -1.2588e+00],
#          [-1.0065e+00, -2.3326e-01,  7.2125e-01,  ..., -9.3784e-01,
#            6.7895e-01, -5.6495e-02],
#          ...,
#          [-1.3950e+00, -1.0698e-01, -1.0942e+00,  ...,  8.2279e-01,
#            4.0368e-04, -4.0546e-01],
#          [ 1.1677e+00,  5.4296e-01,  1.3000e+00,  ..., -3.3278e-01,
#           -9.4725e-01,  2.7194e+00],
#          [-2.2041e+00,  1.1179e+00, -9.1389e-02,  ..., -5.2201e-01,
#           -4.3238e-01,  1.0636e+00]], requires_grad=True),
#  Parameter containing:
#  tensor([0., 0., 0.,  ..., 0., 0., 0.], requires_grad=True),
#  Parameter containing:
#  tensor([0.2835, 0.7367, 0.4137,  ..., 0.2914, 0.2943, 0.2942],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.0346,  0.0696, -0.0352,  ...,  0.0267,  0.0271,  0.0333],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.8142,  0.4449, -0.6297,  ..., -0.2346, -1.1304, -0.1365],
#          [-0.3567, -0.1558,  0.0368,  ..., -0.0033, -0.3952,  0.2438],
#          [ 0.1553,  0.0234, -0.4796,  ...,  0.3068,  0.3784,  0.0249],
#          ...,
#          [ 0.0673,  0.0321, -0.1377,  ..., -0.0045,  0.6537,  0.1849],
#          [ 0.0791,  0.0886,  0.8673,  ...,  0.0545,  0.8118, -0.4419],
#          [ 0.1327, -0.1567,  0.0447,  ..., -0.0229,  0.3394, -0.8922]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-0.1135, -0.0005, -0.1175,  ..., -0.1360, -0.0291,  0.0085],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.4497,  0.7690, -0.3658,  ..., -0.0251,  0.2841, -0.6373],
#          [-0.7337, -2.0492, -0.5186,  ..., -3.0517,  0.3779,  0.9041],
#          [-0.7010, -0.1034, -0.5511,  ...,  0.5838, -0.0622,  0.3409],
#          ...,
#          [-0.1821, -0.1102,  0.6952,  ...,  0.5123, -0.4601,  0.1992],
#          [ 0.4793, -0.1837, -0.4549,  ..., -1.2702,  0.1318, -0.6040],
#          [ 1.0425, -0.0387,  0.5133,  ..., -0.1092, -0.8561, -0.3839]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([  9.4879, -69.6476,  -7.8813,  ...,  -5.4499,   2.1274,   0.7397],
#         requires_grad=True),
#  Parameter containing:
#  tensor([4.3309, 4.5348, 4.2496,  ..., 4.0724, 3.1521, 2.9960],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.5858,  0.5105, -0.2433,  ...,  0.4776,  0.3044,  0.2585],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0.6979, 0.1754, 0.5850,  ..., 0.6502, 0.4479, 0.5241],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0.0318, 0.0111, 0.2093,  ..., 0.0440, 0.0162, 0.0407],
#         requires_grad=True)]

# %% [markdown]
# ### Further finetuning using labeled data

# %%
class SubprocessDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels
    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels['input_ids'][idx]) # torch.tensor(self.labels[idx])
        return item # input_ids, attention_mask, labels
    def __len__(self):
        return len(self.labels['input_ids']) # len(self.labels)

# %%
model_name = 'google/pegasus-large'
torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'
tokenizer = PegasusTokenizerFast.from_pretrained(model_name)
model = PegasusForConditionalGeneration.from_pretrained(model_name, return_dict=True).to(torch_device)

# %%
# load
epoch = 4
optimizer = AdamW(model.parameters(), weight_decay=0.01, lr=5e-5)
output_model = './models/kepler_pegasus_{}_epoch.pth'.format(epoch)
checkpoint = torch.load(output_model)
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# %%
with open('./train_subprocess.json', 'r') as f:
    subprocess = json.load(f)

# %%
subprocess_text = subprocess['document']
subprocess_summary = subprocess['summary']
unique_idx = np.unique(subprocess_summary, return_index=True)[1]
subprocess_text = [subprocess_text[x] for x in unique_idx]
subprocess_summary = [subprocess_summary[x] for x in unique_idx]
subprocess_flows_extracted = [subprocess['flows_extracted'][x] for x in unique_idx]
# subprocess_text = [subprocess_text[x] for x in np.sort(unique_idx)]
# subprocess_summary = [subprocess_summary[x] for x in np.sort(unique_idx)]
# subprocess_flows_extracted = [subprocess['flows_extracted'][x] for x in np.sort(unique_idx)]

# %%
len(subprocess_summary)
# Out:
# 153

# %%
def subprocess_tokenize_data(texts, labels):
    encodings = tokenizer(texts, truncation=True, padding=True)
    decodings = tokenizer(labels, truncation=True, padding=True)
    subprocess_tokenized = SubprocessDataset(encodings, decodings)
    return subprocess_tokenized

# %%
subprocess_labeled_dataset = subprocess_tokenize_data(subprocess_text[:133], subprocess_summary[:133])

subprocess_labeled_dataloader = DataLoader(
    subprocess_labeled_dataset, shuffle=True, batch_size=1
)

for subprocess_batch in subprocess_labeled_dataloader:
    break
print({k: v.shape for k, v in subprocess_batch.items()})
# Out:
# {'input_ids': torch.Size([1, 105]), 'attention_mask': torch.Size([1, 105]), 'labels': torch.Size([1, 22])}

# %%
num_epochs = 11
num_training_steps = num_epochs * len(subprocess_labeled_dataloader)
lr_scheduler = get_scheduler(
    "linear",
    optimizer=optimizer,
    num_warmup_steps=500,
    num_training_steps=num_training_steps,
)
print(num_training_steps)
# Out:
# 1463

# %%
def save(model, optimizer, output_model):
    torch.save({
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict()
    }, output_model)

# %%
progress_bar = tqdm(range(num_training_steps))

model.train()
for epoch in range(num_epochs):
    for subprocess_batch in subprocess_labeled_dataloader:        
        batch = {k: v.to(torch_device) for k, v in subprocess_batch.items()}
        outputs = model(**batch)
        loss = outputs.loss
        loss.backward()

        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        progress_bar.update(1)
        
    if epoch % 2 == 0:
        output_model = './models_subprocess_2/kepler_pegasus_subprocess_{}_epoch.pth'.format(epoch)
        save(model, optimizer, output_model)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1463.0), HTML(value='')))

# %% [markdown]
# ##### Check results -- Inference

# %%
epoch = 6
output_model = './models_subprocess_2/kepler_pegasus_subprocess_{}_epoch.pth'.format(epoch)
checkpoint = torch.load(output_model)
model.load_state_dict(checkpoint['model_state_dict'])
model.eval()
# Out:
# PegasusForConditionalGeneration(
#   (model): PegasusModel(
#     (shared): Embedding(96103, 1024, padding_idx=0)
#     (encoder): PegasusEncoder(
#       (embed_tokens): Embedding(96103, 1024, padding_idx=0)
#       (embed_positions): PegasusSinusoidalPositionalEmbedding(1024, 1024)
#       (layers): ModuleList(
#         (0): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (6): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (7): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (8): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (9): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (10): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (11): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (12): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (13): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (14): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (15): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): PegasusDecoder(
#       (embed_tokens): Embedding(96103, 1024, padding_idx=0)
#       (embed_positions): PegasusSinusoidalPositionalEmbedding(1024, 1024)
#       (layers): ModuleList(
#         (0): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (6): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (7): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (8): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (9): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (10): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (11): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (12): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (13): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (14): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (15): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (lm_head): Linear(in_features=1024, out_features=96103, bias=False)
# )

# %%
batch = tokenizer(subprocess_text[133:], truncation=True, padding='longest', return_tensors="pt").to(torch_device)
translated = model.generate(**batch)
tgt_text = tokenizer.batch_decode(translated, skip_special_tokens=True)

# %%
n = -4

# %%
subprocess_text[133:][n]
# Out:
# 'payment by creditcard, payment by bank-account transfer, payment by PayPal'

# %%
subprocess_summary[133:][n]
# Out:
# 'payment'

# %%
tgt_text
# Out:
# ['Manage account',
#  'Editing and proofreading',
#  'Check compliance',
#  'Check for duplicates',
#  'create insurance proposal',
#  'Check completeness',
#  'Fill journey information',
#  'Fill loan proposal',
#  'write a letter to applicant',
#  'Membership process',
#  'Check if information is complete',
#  'NummerZwei()',
#  'archive invoice per payment date',
#  'Booking',
#  'Negotiate terms and conditions',
#  'Check if cash is available',
#  'payment by installments',
#  'Check completeness and car existence',
#  'Traffic infringement resolution. processing traffic infringement',
#  'Booking']

# %%
reesults = {'subprocess_text': subprocess_text[133:], 'subprocess_summary': subprocess_summary[133:],
           'model_output':  tgt_text,'subprocess_flows_extracted': subprocess_flows_extracted[133:]}

with open('results_subprocess_2.json', 'w') as f:
    json.dump(reesults, f)

# %%
# taking eos as sentence representation
# use encodings itself (or random generated text) as labels, decoder_input_ids needed for graph data output...
# create some sort of assertions? to make sure that the loss is calculated correctly
# input data design questions (input data repetitions of subprocess side)
# summarisation evaluation metrics questions

# list of planned experiments - hypothesis vs. realities
# thesis - experiment sections - data & sentence representation & KE loss definitions & evaluation metrics
# github colab...
# https://wandb.ai/site

# %%
# def freeze_params(model: nn.Module):
#     """Set requires_grad=False for each of model.parameters()"""
#     for par in model.parameters():
#         par.requires_grad = False

# def freeze_embeds(model):
#     """Freeze token embeddings and positional embeddings for bart, just token embeddings for t5."""
#     model_type = model.config.model_type

#     if model_type in ["t5", "mt5"]:
#         freeze_params(model.shared)
#         for d in [model.encoder, model.decoder]:
#             freeze_params(d.embed_tokens)
#     elif model_type == "fsmt":
#         for d in [model.model.encoder, model.model.decoder]:
#             freeze_params(d.embed_positions)
#             freeze_params(d.embed_tokens)
#     else:
#         freeze_params(model.model.shared)
#         for d in [model.model.encoder, model.model.decoder]:
#             freeze_params(d.embed_positions)
#             freeze_params(d.embed_tokens)
# freeze_embeds(model)

# %%
class KeplerPegasusModel_test(nn.TripletMarginLoss):
    
    def __init__(self, model, margin: float = 1.0, p: float = 2., eps: float = 1e-6, swap: bool = False, size_average=None,
                 reduce=None, reduction: str = 'mean'):
        super().__init__(margin, p, eps, swap, size_average, reduce, reduction)
        self.model = model
        
    def forward(self, anchor, positive, negative):
        triplet_margin_loss = F.triplet_margin_loss(anchor, positive, negative, margin=self.margin, p=self.p,
                                 eps=self.eps, swap=self.swap, reduction=self.reduction)       
        return triplet_margin_loss

# %%
anchor = encoder_output[0][eos_idx[0]]
positive = encoder_output[1][eos_idx[1]]
negative = encoder_output[2][eos_idx[2]]

# %%
model_K = KeplerPegasusModel_test(model)
loss_1 = model_K(anchor, positive, negative)
loss_1
# Out:
# tensor(0.0858, grad_fn=<MeanBackward0>)

# %%
triplet_margin_loss = nn.TripletMarginLoss(margin=1.0, p=2)
loss_2 = triplet_margin_loss(anchor, positive, negative)
loss_2
# Out:
# tensor(0.0858, grad_fn=<MeanBackward0>)

# %%
loss_1 == loss_2
# Out:
# tensor(True)

# %%
# triplet_loss = nn.TripletMarginLoss(margin=1.0, p=2)
# anchor = torch.randn(100, 128, requires_grad=True)
# positive = torch.randn(100, 128, requires_grad=True)
# negative = torch.randn(100, 128, requires_grad=True)
# output = triplet_loss(anchor, positive, negative)
# output.backward()

# %%
# anchor_output = ...  # shape [None, 128]
# positive_output = ...  # shape [None, 128]
# negative_output = ...  # shape [None, 128]

# d_pos = tf.reduce_sum(tf.square(anchor_output - positive_output), 1)
# d_neg = tf.reduce_sum(tf.square(anchor_output - negative_output), 1)

# loss = tf.maximum(0., margin + d_pos - d_neg)
# loss = tf.reduce_mean(loss)

# #         d_pos = torch.sum(torch.square(anchor_output - positive_output), -1)
# #         d_neg = torch.sum(torch.square(anchor_output - negative_output), -1)
# #         tripletloss = torch.maximum(0., margin + d_pos - d_neg)
# #         loss = torch.mean(loss)

# %%
# class SubprocessDataset(Dataset):
#     def __init__(
#         self,
#         data: pd.DataFrame,
#         tokenizer: PegasusTokenizerFast
#     ):                
#         self.data = data
#         self.tokenizer = tokenizer
        
#     def __len__(self):
#         return len(self.data)  
    
#     def __getitem__(self, idx:int):
#         data_row = self.data.iloc[idx]
#         text = data_row['text']
#         masked_sent = data_row['masked_sent']
#         text_encoding = self.tokenizer(text, truncation=True, padding=True)
#         masked_sent_encoding = self.tokenizer(text, truncation=True, padding=True)
#         return dict(
#             text=text,
#             masked_sent=masked_sent,
#             text_input_ids=text_encoding['input_ids'].flatten(),
#             text_attetion_mask=text_encoding['attention_mask'].flatten(),
#             labels = masked_sent_encoding['input_ids'].flatten()
#         )

# %%
# import pytorch_lightning as pl

# class SubprocessDataModule(pl.LightningDataModule):
#     def __init__(
#         self,
#         train_df: pd.DataFrame,
#         tokenizer: PegasusTokenizerFast,
#         batch_size: int = 1
#     ):
#         super().__init__()
        
#         self.train_df = train_df
#         self.tokenizer = tokenizer
#         self.batch_size = batch_size
        
#     def setup(self, stage=None):
#         self.train_dataset = SubprocessDataset(self.train_df, self.tokenizer)
        
#     def train_dataloader(self):
#         return DataLoader(
#             self.train_dataset,
#             batch_size = self.batch_size,
#             shuffle=True,
#             num_workers=8
#         )

# %%
# n_epoch = 1
# batch_size = 1
# data_module = SubprocessDataModule(train_df, tokenizer, batch_size=batch_size)

# %% [markdown]
# ### Model

# %%
# class KeplerPegasusModel(pl.LightningModule):
    
#     def __init__(self):
#         super().__init__()
#         self.model = PegasusForConditionalGeneration.from_pretrained(model_name, return_dict=True).to(torch_device)
        
#     def forward(self, input_ids, attention_mask, labels):
#         output = self.model(input_ids, attention_mask=attention_mask, labels=labels)
#         return output.loss, output.logits
    
#     def training_step(self, batch, batch_idx):
#         input_ids = batch['text_input_ids']
#         attention_mask = batch['text_attetion_mask']
#         labels = batch['labels']
        
#         loss, outputs = self(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
#         self.log("train_loss", loss, prog_bar=True, logger=True)
#         return loss
    
#     def configure_optimizers(self):
#         return AdamW(self.parameters(), lr=0.0001)

# %%
# model = KeplerPegasusModel()

# %%
# from pytorch_lightning.callbacks import ModelCheckpoint
# from pytorch_lightning.loggers import TensorBoardLogger

# %load_ext tensorboard
# %tensorboard --logdir ./lightning_logs

# %%
# checkpoint_callback = ModelCheckpoint(
#     dirpath = 'checkpoints',
#     filename = 'best-checkpoint',
#     save_top_k = 1,
#     verbose = True,
# #     monitor = 'val_loss',
#     mode = 'min'
# )

# logger = TensorBoardLogger('lightning_logs', name='process-abstraction-pretrain')

# trainer = pl.Trainer(
#     logger=logger,
#     enable_checkpointing=checkpoint_callback,
#     max_epochs=n_epoch,
#     gpus=0,
#     progress_bar_refresh_rate=30,
#     log_every_n_steps=1
# )
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs

# %%
# trainer.fit(model, data_module)
# Out:
#   | Name  | Type                            | Params
# ----------------------------------------------------------
# 0 | model | PegasusForConditionalGeneration | 570 M
# ----------------------------------------------------------
# 568 M     Trainable params
# 2.1 M     Non-trainable params
# 570 M     Total params
# 2,283.188 Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/I543118/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/I543118/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'SubprocessDataset' on <module '__main__' (built-in)>
# /Users/I543118/opt/anaconda3/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:688: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")

# %%
# train_texts = ['<mask_1>, Make sure there is no clash between social event and orientation sessions, Advertise social events for new students, Conduct the social event, Post event pictures in social network',
#  '<mask_1>, Verify Sales Quote, Analyze RFQ and produce L&M estimates, Generate overhead costs and determine pricing options, Review Pricing Options and Generate Sales Quote, Sales Quote Delivered',
#  '<mask_1>, <mask_1>, deny request, accept request, check security, accept request, accept request']

# train_labels = ['Create social events',
#  'RFQ Recieved',
#  'check assigment rule , check credit rating']

# subprocess_dataset = pd.DataFrame(list(zip(train_texts, train_labels)), columns = ['text', 'masked_sent'])
# subprocess_dataset

# %%
# class PegasusDataset(torch.utils.data.Dataset):
#     def __init__(self, encodings, labels):
#         self.encodings = encodings
#         self.labels = labels
#     def __getitem__(self, idx):
#         item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
#         item['labels'] = torch.tensor(self.labels['input_ids'][idx])  # torch.tensor(self.labels[idx])
#         return item
#     def __len__(self):
#         return len(self.labels['input_ids'])  # len(self.labels)

# %%
# def tokenize_data(texts, labels):
#         encodings = tokenizer(texts, truncation=True, padding=True)
#         decodings = tokenizer(labels, truncation=True, padding=True)
#         dataset_tokenized = PegasusDataset(encodings, decodings)
#         return dataset_tokenized

# train_dataset = tokenize_data(train_texts, train_labels)

# %%
# train_dataloader = DataLoader(
#     train_dataset, shuffle=True, batch_size=2, collate_fn=DataCollator
# )
# for batch in train_dataloader:
#     break
# print({k: v.shape for k, v in batch.items()})
# print(batch)
