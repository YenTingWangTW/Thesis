# %%
import re
import json
import glob
import numpy as np
import pandas as pd

# %%
def CustomParser(data):
#     import json
    j1 = json.loads(data)
    return j1

# %%
def subprocess_exist(shapes):
    subprocess = False
    for shape in shapes:
        shape_stencil = shape['stencil']['id']
        if shape_stencil == 'Subprocess':
            subprocess = True
    return subprocess

# %%
# %%time

for f in glob.glob('../../thesis_data/data_with_meta/*_meta.csv'):
    with open(f) as csv:
        data = pd.read_csv(csv, converters={'Model JSON':CustomParser})
        data = data[data['Type'] == 'BPMN 2.0'] 
        for index, row in data.iterrows():
            model_json = row['Model JSON']
            shapes = model_json['childShapes']
            if subprocess_exist(shapes) and 'properties' in model_json.keys() and 'language' in model_json['properties'].keys() and model_json['properties']['language'] == 'English':
                file = './BPMAI2/'+row['Model ID']+'.json'
                model_json.update({'csv_id': f})
                with open(file, 'w') as new_file:
                    json.dump(row['Model JSON'], new_file)
# Out:
# CPU times: user 8min 23s, sys: 16.9 s, total: 8min 40s
# Wall time: 8min 42s

# %%
def process_flow(shapes):
    shapes_id = {}
    follows = {}
    flow = {}
    tasks_subprocesses = ['Task', 'CollapsedSubprocess', 'Subprocess']
    shapes_unwanted = ['DataObject', 'ITSystem', 'TextAnnotation', 
                      ' Association_Undirected', 'Association_Unidirectional', 'MessageFlow']
    outputs = [shapes_id, follows, flow]

    for shape in shapes:
        shape_stencil = shape['stencil']['id']
        shape_ID = shape['resourceId']
        if shape_stencil in shapes_unwanted:
            continue
        shapes_id.update({shape_ID: shape_stencil})
        
        outgoingShapes = [s['resourceId'] for s in shape['outgoing']]
        if shape_ID not in follows.keys():
            follows[shape_ID] = outgoingShapes
    
        if shape_stencil in tasks_subprocesses:
            if not shape['properties']['name'] == "":
                flow[shape_ID] = shape['properties']['name'].replace('\n', ' ').replace('\r', '').replace('  ', ' ')
            else:
                flow[shape_ID] = 'Task or Subprocess'
        else:
            if 'name' in shape['properties'] and not shape['properties']['name'] == "":
                flow[shape_ID] = shape_stencil + " (" + shape['properties']['name'].replace('\n', ' ').replace('\r', '').replace('  ', ' ') + ")"
            else:
                flow[shape_ID] = shape_stencil

    return outputs

# %%
def process_subprocess_with_label(shapes):
    shapes_id = {}
    follows = {}
    flow = {}
    subprocess_name = []
    outputs = [shapes_id, follows, flow]
    for shape in shapes:
        shape_stencil = shape['stencil']['id']
        shape_ID = shape['resourceId']
        if shape_stencil == 'SequenceFlow':
            outgoingShapes = [s['resourceId'] for s in shape['outgoing']]
            if shape_ID not in follows.keys():
                follows[shape_ID] = outgoingShapes
            
        if shape_stencil in ['Pool', 'Lane']:
            results, names = process_subprocess_with_label(shape['childShapes'])
            for o, r in zip(outputs, results):
                o.update(r)
            subprocess_name += names
            
        if shape_stencil == 'Subprocess':
            results = process_flow(shape['childShapes'])
            if 'name' in shape['properties'] and not shape['properties']['name'] == "":
                for o, r in zip(outputs, results):
                    o.update(r)
                name = shape['properties']['name'].replace('\n', ' ').replace('\r', '').replace('  ', ' ')
                subprocess_name.append(name)
                
    return outputs, subprocess_name

# %%
def sort_process_flows(flow, directly_follows, shapes_wanted, gateways_count, temp_closing_count):
    process_flow = []

    for flow_object in flow:
        if flow_object in shapes_wanted and flow_object not in temp_closing_count.keys():
            process_flow.append(flow_object)
        
        if flow_object in gateways_count.keys() and flow_object not in temp_closing_count.keys():
            process_flow.append(flow_object)
            
        if flow_object in temp_closing_count.keys():
            count = temp_closing_count[flow_object]-1
            temp_closing_count.update({flow_object: count})
            if temp_closing_count[flow_object] == 0:
                process_flow.append(flow_object)
            else:
                continue
                    
        if flow_object in directly_follows.keys() and directly_follows[flow_object]: 
            flow = directly_follows[flow_object]
            result = sort_process_flows(flow, directly_follows, shapes_wanted, gateways_count, temp_closing_count)
            process_flow = process_flow + result
            
    return process_flow

# %%
subprocess = {}
file_id = {}
temp_training_data = {}
subprocess_names = {}

for i, file in enumerate(glob.glob('./BPMAI2/*.json')):
    file_id.update({i: file})
    with open(file, 'r') as f:
        model_json = json.load(f)
        (shapes_id, directly_follows, flows), subprocess_name = process_subprocess_with_label(model_json['childShapes'])
        
        stencils = set()
        tasks_subprocesses_id = set()
        start_events_id = set()
        end_events_id = set()
        int_events_id = set()
        gateways_count = {}
        closing_gateways_id = set()
        shapes_unwanted_id = set()
        tasks_subprocesses = ['Task', 'CollapsedSubprocess', 'Subprocess']
        gateways = ['Exclusive_Databased_Gateway', 'InclusiveGateway', 'ParallelGateway']
        shapes_unwanted = ['DataObject', 'ITSystem', 'TextAnnotation', 
                        'Association_Undirected', 'Association_Unidirectional', 'MessageFlow']

        for s in shapes_id.keys():
            stencils.add(shapes_id[s])
            if re.match('(Start.)', shapes_id[s]):
                start_events_id.add(s)
            if re.match('(End.)', shapes_id[s]):
                end_events_id.add(s)
            if re.match('(Intermediate.)', shapes_id[s]):
                int_events_id.add(s)
            if shapes_id[s] in gateways:
                gateways_count.update({s: len(directly_follows[s])})
                if len(directly_follows[s]) == 1:
                    closing_gateways_id.add(s)
            if shapes_id[s] in tasks_subprocesses:
                tasks_subprocesses_id.add(s)
            if shapes_id[s] in shapes_unwanted:
                shapes_unwanted_id.add(s)

        for f in directly_follows.copy():
            if f in shapes_unwanted_id:
                directly_follows.pop(f)
            if f in directly_follows.keys() and directly_follows[f]:
                for r in directly_follows[f]:
                    if r in shapes_unwanted_id:
                        directly_follows[f].remove(r)

        closing_gateways_tasks_count = {}
        for g in closing_gateways_id:
            count = 0
            for f in directly_follows.values():
                count += sum(1 if re.match(g, x) else 0 for x in f)
            closing_gateways_tasks_count[g] = count

        for t in tasks_subprocesses_id:
            count = 0
            for f in directly_follows.values():
                count += sum(1 if re.match(t, x) else 0 for x in f)
            if count > 1:
                closing_gateways_tasks_count[t] = count

        for e in end_events_id:
            count = 0
            for f in directly_follows.values():
                count += sum(1 if re.match(e, x) else 0 for x in f)
            if count > 1:
                closing_gateways_tasks_count[e] = count

        shapes_wanted = set.union(tasks_subprocesses_id, start_events_id, end_events_id, int_events_id)
        temp_closing_count = closing_gateways_tasks_count.copy()
        file_data = []
        for s in start_events_id:
            data = []
            label = []
            flow = directly_follows[s]
            result = sort_process_flows(flow, directly_follows, shapes_wanted, gateways_count, temp_closing_count)
            result.insert(0,s)
            result_copy = result.copy()    
            names = flows  

            for n, obj in enumerate(result_copy):
                if (obj in start_events_id) or (obj in int_events_id) or (obj in end_events_id):
                    if obj in names:
                        res = re.findall(r'\(.*?\)', names[obj])
                        if res:
                            names[obj] = res[0][1:-1]
                        else:
                            result.remove(obj)
                if obj in gateways_count:
                    result.remove(obj)

            for r in result:
                if r in names:
                    data.append(names[r])
            file_data.append([x.lower() for x in data])

        if len(file_data):
            temp_training_data.update({i: file_data})
            subprocess_names.update({i: [x.lower() for x in subprocess_name]})

    subprocess_train_dataset = {'document': temp_training_data, 'subprocess_names': subprocess_names,
                                'file_id': file_id}

# %%
from IPython.display import clear_output

doc = subprocess_train_dataset['document']
label = subprocess_train_dataset['subprocess_names']
subprocess_with_label = {}

for i, (d_v, l_v) in enumerate(zip(doc.values(), label.values())):
    for n, (d, l) in enumerate(zip(d_v, l_v)):
        clear_output(wait=True)
        print(i,'\n', l, '\n', d)
        need = input('need? ')
        if need == 'y':
            key = str(i)+'_'+str(n)
            subprocess_with_label.update({key: {l: d}})
# Out:
# 132
#  assign inquiry
#  ['the inquiry is new', 'read e-mail information', 'read mail content', 'write content as body of notification', "read sender's e-mail address ", 'identify staff member from database', 'write name staff member as "sender" in notification', 'read mail subject', 'write subject as head of notification', 'notification created']

# %%
subprocess_with_label.keys()
# Out:
# dict_keys(['0_0', '0_1', '0_2', '1_0', '2_0', '2_1', '3_0', '5_0', '6_0', '7_0', '7_1', '7_2', '7_3', '7_4', '7_5', '11_0', '12_0', '13_0', '14_0', '15_0', '15_1', '17_0', '17_1', '18_0', '18_1', '19_0', '20_0', '25_0', '26_0', '31_0', '31_1', '32_0', '32_1', '33_0', '40_0', '41_0', '42_0', '43_0', '45_0', '45_1', '45_2', '49_0', '52_0', '54_0', '54_1', '54_2', '56_0', '56_1', '58_0', '62_0', '62_1', '62_2', '62_3', '62_4', '62_5', '62_6', '62_7', '63_0', '65_0', '67_0', '68_0', '69_0', '71_0', '71_1', '72_0', '73_0', '75_0', '75_1', '76_0', '77_0', '77_2', '78_0', '78_1', '80_0', '84_0', '84_1', '84_2', '88_0', '89_0', '91_0', '91_1', '96_0', '97_0', '98_0', '99_0', '99_1', '100_0', '101_0', '102_0', '104_0', '105_0', '107_0', '111_0', '111_1', '113_0', '113_1', '113_2', '115_0', '118_0', '118_1', '118_2', '119_0', '122_0', '122_1', '122_2', '122_3', '122_4', '123_0', '129_0', '130_0', '131_0', '132_0', '132_1'])

# %%
with open('new_labeled_dataset_subprocess.json', 'w') as f:
    json.dump(subprocess_with_label, f)

# %%
with open('new_labeled_dataset_subprocess.json', 'r') as f:
    json_data = json.load(f)

# %%
subprocesses = json_data.values()
labels = []
docs = []
for s in subprocesses:
    labels.append(list(s.keys())[0])
    docs.append(list(s.values())[0])

# %%
len(docs)
# Out:
# 112

# %%
unique_docs, idx_start = np.unique(docs, return_index=True)
len(unique_docs)
# Out:
# /Users/I543118/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/arraysetops.py:270: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ar = np.asanyarray(ar)
# 97

# %%
unique_subprocesses = {}
for i, (l, d) in enumerate(zip(labels, docs)):
    if i in idx_start:
        unique_subprocesses.update({i: {l: d}})

# %%
subprocess_labels = []
subprocess_docs = []
for i, s in unique_subprocesses.items():
    clear_output(wait=True)
    s_k = list(s.keys())[0]
    s_v = list(s.values())[0]
    s_v = ', '.join(s_v)
    print(i,'\n', s_k, '\n', s_v)
    change_name = input('change name? ')
    if change_name != "":
        subprocess_labels.append(change_name)
    else:
        subprocess_labels.append(s_k)
    subprocess_docs.append(s_v)
# Out:
# 111
#  assign inquiry
#  the inquiry is new, read e-mail information, read mail content, write content as body of notification, read sender's e-mail address , identify staff member from database, write name staff member as "sender" in notification, read mail subject, write subject as head of notification, notification created

# %%
x =  "enroll"
num_d = len(x.split(', '))
num_d
# Out:
# 1

# %%
document = []
summary = []
for l, d in zip(subprocess_labels, subprocess_docs):
    num_d = len(d.split(', '))
    if num_d > 2:
        document.append(d)
        summary.append(l)
        
filtered_subprocesses = {'document': document, 'summary': summary}

# %%
len(document)
# Out:
# 87

# %%
for i, (s, d) in enumerate(zip(summary, document)):
    clear_output(wait=True)
    print(i, "\n", s, "\n", d)
    input('check: ')
# Out:
# 86
#  assign inquiry
#  the inquiry is new, read e-mail information, read mail content, write content as body of notification, read sender's e-mail address , identify staff member from database, write name staff member as "sender" in notification, read mail subject, write subject as head of notification, notification created

# %%
with open('final_new_labeled_dataset.json', 'w') as f:
    json.dump(filtered_subprocesses, f)

# %%
# year 1 year 2 - search and check - handle phd program

# delete 81 - essensvorbereitung
# handle num of tasks that are lower than 3 - delete?

# %%
num = 10000
file = '../../thesis_data/data_with_meta/{}_meta.csv'.format(num)

# %%
data = pd.read_csv(file)
data.head()
# Out:
#                            Model ID                   Organization ID  \
# 0  b3521d410a3c4912ad2bd9355af717a1  04f6934d4088427a84031c24b27f87d9
# 1  c830688c44104ba3b7c27c65b0e12dd7  04f6934d4088427a84031c24b27f87d9
# 2  f47c5ac96a0b4ce3ba20f170b83cd274  04f6934d4088427a84031c24b27f87d9
# 3  ff08bc48516547dd9362bd5fa057b2bb  04f6934d4088427a84031c24b27f87d9
# 4  1ab5bbbe4027423b95f225e6c5a41625  04fa7f859249401a94e7cea3e6a1f4aa
#
#                                           Model JSON  Description  \
# 0  {"resourceId":"canvas","formats":{},"ssextensi...          NaN
# 1  {"resourceId":"canvas","formats":{},"ssextensi...          NaN
# 2  {"resourceId":"canvas","formats":{"documentati...          NaN
# 3  {"resourceId":"canvas","formats":{},"ssextensi...          NaN
# 4  {"resourceId":"canvas","formats":{"processgoal...          NaN
#
#                                        Name Type  \
# 0  Level  2 - Process Area: Human Resources  NaN
# 1                       Employee Onboarding  NaN
# 2                    Receipt of Application  NaN
# 3                          Verify applicant  NaN
# 4             Level 1 - Value Chain ACME AG  NaN
#
#                                          Namespace
# 0  http://www.signavio.com/stencilsets/processmap#
# 1              http://b3mn.org/stencilset/bpmn2.0#
# 2              http://b3mn.org/stencilset/bpmn2.0#
# 3         http://signavio.com/stencilsets/dmn-1.0#
# 4  http://www.signavio.com/stencilsets/processmap#

# %%
list(data.Name.values)
# Out:
# ['As-is_V1',
#  'Level 1 - Value Chain ACME AG',
#  'Procurement of Work Equipment',
#  'BPMNmodel_NEWv1',
#  'Check quantity and quality',
#  'As-is process ',
#  'Employee Onboarding',
#  'Receipt of Goods',
#  'Level 2 - Process Area: Order Processing',
#  'Group Assignment1_v1',
#  'Simulation and Modelling',
#  'Assignment 1 ',
#  'Receipt of Application',
#  'Level 2 - Process Area: Product Development',
#  'Level  2 - Process Area: Human Resources',
#  'BPMN_assignment2',
#  'Procure parts',
#  'Verify applicant',
#  'Procurement of Work Equipment',
#  'Level 2 - Process Area: Product Development',
#  'Receipt of Application',
#  'Level 1 - Value Chain ACME AG',
#  'Verify applicant',
#  'Level  2 - Process Area: Human Resources',
#  'Procure parts',
#  'Receipt of Goods',
#  'Check quantity and quality',
#  'Level 2 - Process Area: Order Processing',
#  'Employee Onboarding',
#  'ΔΙΕΚΠΕΡΑΙΩΣΗ ΑΙΤΗΣΗΣ ΧΟΡΗΓΗΣΗΣ ΑΔΕΙΑΣ',
#  'Level 2 - Process Area: Product Development',
#  'Level 2 - Process Area: Order Processing',
#  'Level  2 - Process Area: Human Resources',
#  'Receipt of Goods',
#  'Level 1 - Value Chain ACME AG',
#  'Check quantity and quality',
#  'Procure parts',
#  'Receipt of Application',
#  'Procurement of Work Equipment',
#  'Verify applicant',
#  'Employee Onboarding',
#  'Teile beschaffen v2',
#  'Teile beschaffen',
#  'Bewerbungseingang',
#  'Neuer Prozess',
#  'Mitarbeiter Onboarding',
#  'Ebene 1 - Prozesslandkarte ACME AG',
#  'Arbeitsmittel beschaffen',
#  'Ebene  2 - Prozessbereich: Personalwesen',
#  'Ebene 2 - Prozessbereich: Produktentwicklung',
#  'Wareneingang',
#  'Menge und Qualität überprüfen',
#  'Ebene 2 - Prozessbereich: Auftragsdurchführung',
#  'Teile beschaffen',
#  'Bewerber prüfen',
#  'Level 2 - Process Area: Order Processing',
#  'Level  2 - Process Area: Human Resources',
#  'Procurement of Work Equipment',
#  'Check quantity and quality',
#  'Receipt of Application',
#  'Receipt of Goods',
#  'Employee Onboarding',
#  'Verify applicant',
#  'Level 1 - Value Chain ACME AG',
#  'Level 2 - Process Area: Product Development',
#  'Procure parts',
#  'Mitarbeiter Onboarding',
#  'Bewerber prüfen',
#  'Ebene  2 - Prozessbereich: Personalwesen',
#  'Ebene 2 - Prozessbereich: Produktentwicklung',
#  'Ebene 2 - Prozessbereich: Auftragsdurchführung',
#  'Bewerbungseingang',
#  'Teile beschaffen',
#  'Arbeitsmittel beschaffen',
#  'Menge und Qualität überprüfen',
#  'Wareneingang',
#  'Ebene 1 - Prozesslandkarte ACME AG',
#  'Procurement of Work Equipment',
#  'Receipt of Goods',
#  'Employee Onboarding',
#  'Receipt of Application',
#  'Level  2 - Process Area: Human Resources',
#  'Verify applicant',
#  'Level 2 - Process Area: Product Development',
#  'Procure parts',
#  'Ergasia',
#  'Check quantity and quality',
#  'Level 2 - Process Area: Order Processing',
#  'PO Demo',
#  'Level 1 - Value Chain ACME AG',
#  'Sample Process',
#  'Level  2 - Process Area: Human Resources',
#  'Check quantity and quality',
#  'Procurement of Work Equipment',
#  'Level 2 - Process Area: Order Processing',
#  'Procure parts',
#  'Verify applicant',
#  'Receipt of Goods',
#  'Employee Onboarding',
#  'Receipt of Application',
#  'Level 1 - Value Chain ACME AG',
#  'Level 2 - Process Area: Product Development',
#  'Receipt of Goods',
#  'Level  2 - Process Area: Human Resources',
#  'Procurement of Work Equipment',
#  'Level 2 - Process Area: Product Development',
#  'Level 2 - Process Area: Order Processing',
#  'Check quantity and quality',
#  'Procure parts',
#  'Receipt of Application',
#  'Employee Onboarding',
#  'Verify applicant',
#  'Level 1 - Value Chain ACME AG',
#  'Procurement of Work Equipment',
#  'DC2 task 2a (Copy)',
#  'DC2 task 2a draft 3 (Copy)',
#  'DC2 task 2a (Copy)',
#  'Level 2 - Process Area: Order Processing',
#  'Employee Onboarding',
#  'Receipt of Goods',
#  'Level 2 - Process Area: Product Development',
#  'Level 1 - Value Chain ACME AG',
#  'DC2 task 2a draft 3',
#  'Level  2 - Process Area: Human Resources',
#  'Check quantity and quality',
#  'Verify applicant',
#  'Procure parts',
#  'Receipt of Application',
#  'Receipt of Application',
#  'Procesos para el proyecto',
#  'Verify applicant',
#  'Procure parts',
#  'Check quantity and quality',
#  'Receipt of Goods',
#  'Proceso de compras',
#  'Procurement of Work Equipment',
#  'Level 2 - Process Area: Order Processing',
#  'Level 1 - Value Chain ACME AG',
#  'Employee Onboarding',
#  'Produccion',
#  'Procesos para el proyecto (2)',
#  'Level 2 - Process Area: Product Development',
#  'Level  2 - Process Area: Human Resources',
#  'Ebene  2 - Prozessbereich: Personalwesen',
#  'Bewerbungseingang',
#  'Teile beschaffen',
#  'Menge und Qualität überprüfen',
#  'Ebene 1 - Prozesslandkarte ACME AG',
#  'Ebene 2 - Prozessbereich: Auftragsdurchführung',
#  'Arbeitsmittel beschaffen',
#  'Wareneingang',
#  'Ebene 2 - Prozessbereich: Produktentwicklung',
#  'Bewerber prüfen',
#  'Mitarbeiter Onboarding',
#  'Level 1 - Value Chain ACME AG',
#  'Level  2 - Process Area: Human Resources',
#  'Check quantity and quality',
#  'Receipt of Application',
#  'Level 2 - Process Area: Order Processing',
#  'Employee Onboarding',
#  'Verify applicant',
#  'Level 2 - Process Area: Product Development',
#  'Procurement of Work Equipment',
#  'Procure parts',
#  'Receipt of Goods',
#  'Level 1 - Value Chain ACME AG',
#  'Employee Onboarding',
#  'Receipt of Application',
#  'Receipt of Goods',
#  'ex1',
#  'Procure parts',
#  'New Process',
#  'examen',
#  'Level  2 - Process Area: Human Resources',
#  'Check quantity and quality',
#  'Procurement of Work Equipment',
#  'Level 2 - Process Area: Order Processing',
#  'Level 2 - Process Area: Product Development',
#  'Verify applicant',
#  'Mitarbeiter Onboarding',
#  'Arbeitsmittel beschaffen',
#  'Wareneingang',
#  'Menge und Qualität überprüfen',
#  'Ebene  2 - Prozessbereich: Personalwesen',
#  'Ebene 2 - Prozessbereich: Produktentwicklung',
#  'Ebene 2 - Prozessbereich: Auftragsdurchführung',
#  'Ü2',
#  'Bewerbungseingang',
#  'Bewerber prüfen',
#  'Ebene 1 - Prozesslandkarte ACME AG',
#  'Teile beschaffen',
#  'Employee Onboarding',
#  'Level 2 - Process Area: Product Development',
#  'Receipt of Application',
#  'Level  2 - Process Area: Human Resources',
#  'PO Demo',
#  'Check quantity and quality',
#  'New Process',
#  'Level 1 - Value Chain ACME AG',
#  'New Process',
#  'Procure parts',
#  'Verify applicant',
#  'Procurement of Work Equipment',
#  'Level 2 - Process Area: Order Processing',
#  'Receipt of Goods',
#  'Level 2 - Process Area: Product Development',
#  'Claim Handling Department',
#  'New Process',
#  'Procurement of Work Equipment',
#  'Check Policy',
#  'Check quantity and quality',
#  'Employee Onboarding',
#  'Level 1 - Value Chain ACME AG',
#  'Receipt of Application',
#  'Receipt of Goods',
#  'Level 2 - Process Area: Order Processing',
#  'Level  2 - Process Area: Human Resources',
#  'Claim Process',
#  'Insurance Claim Process',
#  'Claim_Process_20030241024',
#  'Procure parts',
#  'Verify applicant',
#  'Level 1 - Value Chain ACME AG',
#  'Check quantity and quality',
#  'Level 2 - Process Area: Order Processing',
#  'Level 2 - Process Area: Product Development',
#  'New Process',
#  'Verify applicant',
#  'Procurement of Work Equipment',
#  'Employee Onboarding',
#  'Procure parts',
#  'Level  2 - Process Area: Human Resources',
#  'Receipt of Application',
#  'Receipt of Goods',
#  'Kodutöö 1, Marili Vihmann',
#  'Emissione ordini - Previsione',
#  'Emissione ordine su ordine cliente',
#  'Controllo materiali e lancio in produzione',
#  'Esercizio 1',
#  'Magnetizzazione rotore',
#  'Lettura barcode avvolgimenti',
#  'Ricezione merce',
#  'BPMN_V0',
#  'Emissione Ordini - Scorta',
#  'Montaggio altri sottogruppi teste',
#  'Jacopo1',
#  'Pianificazione acquisti con codici gestiti su previsione',
#  'BPMN_V1',
#  'Montaggio, collaudo e imballaggio motori e montaggio assi A-C',
#  'colazione_dei_campioni',
#  'BPMN_V3',
#  'Montaggio, collaudo e imballaggio teste',
#  'New Process',
#  "Preventivazione e formulazione dell'offerta",
#  'Controllo Qualità',
#  'Level 1 - Value Chain ACME AG',
#  'Receipt of Application',
#  'Level  2 - Process Area: Human Resources',
#  "Generazione commesse di produzione e piano ordini d'acquisto",
#  'Pianificazione acquisti per codici gestiti a scorta',
#  'Avvolgimento statore',
#  'Ricezione merce',
#  "Preventivazione e formulazione dell'offerta",
#  'Receipt of Goods',
#  'Level 2 - Process Area: Product Development',
#  'Prova',
#  'Procure parts',
#  'BPMN_V2',
#  'Avvolgimento statore',
#  'Procurement of Work Equipment',
#  'Allestimento carrelli',
#  'Employee Onboarding',
#  'Level 2 - Process Area: Order Processing',
#  'Verify applicant',
#  'Check quantity and quality',
#  'Emissione ordini - Previsione',
#  'Receipt of Goods',
#  'FastConnection-GestioneTransiti',
#  'BestBet-Scommesse',
#  'Es1-Parte2-NorciniCostanza',
#  'Level 2 - Process Area: Order Processing',
#  'Procurement of Work Equipment',
#  'ES1-PESCHERELLODOC-NorciniCostanza6293304',
#  'Level 1 - Value Chain ACME AG',
#  'FastConnection-Gestione abbonamenti',
#  'Level  2 - Process Area: Human Resources',
#  'Check quantity and quality',
#  'Level 2 - Process Area: Product Development',
#  'Verify applicant',
#  'Receipt of Application',
#  'Employee Onboarding',
#  'PESCE',
#  'Procure parts',
#  'Airplane-Gestione dei rimborsi dei dipendenti',
#  'Receipt of Application',
#  'Employee Onboarding',
#  'Verify applicant',
#  'Check quantity and quality',
#  'Level 1 - Value Chain ACME AG',
#  'Level 2 - Process Area: Product Development',
#  'Level 2 - Process Area: Order Processing',
#  'Receipt of Goods',
#  'Procure parts',
#  'Procurement of Work Equipment',
#  'Level  2 - Process Area: Human Resources',
#  'Level  2 - Process Area: Human Resources',
#  'Receipt of Application',
#  'Level 2 - Process Area: Order Processing',
#  'Employee Onboarding',
#  'Level 1 - Value Chain ACME AG',
#  'Check quantity and quality',
#  'Procurement of Work Equipment',
#  'Procure parts',
#  'Verify applicant',
#  'Receipt of Goods',
#  'Level 2 - Process Area: Product Development',
#  'Level 2 - Process Area: Product Development',
#  'Procurement of Work Equipment',
#  'Global Bikes',
#  'Level  2 - Process Area: Human Resources',
#  'New Process',
#  'Procure parts',
#  'Check quantity and quality',
#  'Level 2 - Process Area: Order Processing',
#  'Receipt of Application',
#  'Level 1 - Value Chain ACME AG',
#  'Verify applicant',
#  'Employee Onboarding',
#  'Receipt of Goods',
#  'Level 1 - Value Chain ACME AG',
#  'C2_Pregunta 1',
#  'Problem 2.1',
#  'Receipt of Goods',
#  'C3_3',
#  'C1 Verano 2021',
#  'Level 2 - Process Area: Product Development',
#  'Level  2 - Process Area: Human Resources',
#  'Employee Onboarding',
#  'C1_Pregunta 2',
#  'Procurement of Work Equipment',
#  'Receipt of Application',
#  'Nuevo Proceso',
#  'Level 2 - Process Area: Order Processing',
#  'Check quantity and quality',
#  '3.1',
#  'Procure parts',
#  'Problem 2.2',
#  'Problem 2.9',
#  'Problem 2.6',
#  'Verify applicant',
#  'Ayudantía3_1',
#  'Employee Onboarding',
#  'Verify applicant',
#  'Procurement of Work Equipment',
#  'Level 1 - Value Chain ACME AG',
#  'Receipt of Goods',
#  'Receipt of Application',
#  'Level 2 - Process Area: Product Development',
#  'Procure parts',
#  'Check quantity and quality',
#  'Level  2 - Process Area: Human Resources',
#  'Level 2 - Process Area: Order Processing',
#  'Level  2 - Process Area: Human Resources',
#  'Level 2 - Process Area: Product Development',
#  'Employee Onboarding',
#  'Receipt of Application',
#  'Receipt of Goods',
#  'Level 1 - Value Chain ACME AG',
#  'Procurement of Work Equipment',
#  'Procure parts',
#  'Check quantity and quality',
#  'Assignment 1 start ',
#  'Verify applicant',
#  'Level 2 - Process Area: Order Processing',
#  'Wareneingang',
#  'Ebene 2 - Prozessbereich: Produktentwicklung',
#  'Verkauf von digitalen Produkten',
#  'Printmedien aufbereiten',
#  'Ebene 1 - Prozesslandkarte ACME AG',
#  'Ebene  2 - Prozessbereich: Personalwesen',
#  'Kundenauftrag für Messen/Tagungen abwickeln Neu',
#  'Monatlicher GuV-Bericht erstellen',
#  'Überprüfung der Referentenrechnung',
#  'Arbeitsmittel beschaffen',
#  'Neue Prozesslandkarte',
#  'Menge und Qualität überprüfen',
#  'Kundenauftrag für Seminare abwickeln',
#  'Inkasobüro neu',
#  'Referenten buchen',
#  'Semira Planen',
#  'Kundenauftrag für Messen/Tagungen abwickeln',
#  'Kundenauftrag für Messen/Tagungen anlegen',
#  'Bewerber prüfen',
#  'Teile beschaffen',
#  'Mitarbeiter Onboarding',
#  'Kundenauftrag für Seminare anlegen',
#  'Ebene 2 - Prozessbereich: Auftragsdurchführung',
#  'Planung von Tagungen und Messen',
#  'Bewerbungseingang',
#  'Debitor Buchhaltung neu',
#  'Check quantity and quality',
#  'Level 2 - Process Area: Order Processing',
#  'Receipt of Application',
#  'Level 2 - Process Area: Product Development',
#  'Fred Meyer sale proces',
#  'Receipt of Goods',
#  'Level  2 - Process Area: Human Resources',
#  'Procure parts',
#  'Employee Onboarding',
#  'Verify applicant',
#  'Level 1 - Value Chain ACME AG',
#  'Procurement of Work Equipment',
#  'Mitarbeiter Onboarding',
#  'Wareneingang',
#  'Ebene 1 - Prozesslandkarte ACME AG',
#  'Bewerber prüfen',
#  'Ebene 2 - Prozessbereich: Produktentwicklung',
#  'Ebene  2 - Prozessbereich: Personalwesen',
#  'Bewerbungseingang',
#  'Arbeitsmittel beschaffen',
#  'Menge und Qualität überprüfen',
#  'Ebene 2 - Prozessbereich: Auftragsdurchführung',
#  'Teile beschaffen',
#  'Level 2 - Process Area: Order Processing',
#  'Check quantity and quality',
#  'Verify applicant',
#  'Procurement of Work Equipment',
#  'Receipt of Goods',
#  'Level 2 - Process Area: Product Development',
#  'Receipt of Application',
#  'Employee Onboarding',
#  'Level  2 - Process Area: Human Resources',
#  'Level 1 - Value Chain ACME AG',
#  'Procure parts',
#  'Verify applicant',
#  'Check quantity and quality',
#  'Procure parts',
#  'Level 2 - Process Area: Order Processing',
#  'Receipt of Goods',
#  'Level 1 - Value Chain ACME AG',
#  'Employee Onboarding',
#  'Procurement of Work Equipment',
#  'Receipt of Application',
#  'Level  2 - Process Area: Human Resources',
#  'Level 2 - Process Area: Product Development',
#  'Employee Onboarding',
#  'Receipt of Goods',
#  'Check quantity and quality',
#  'Receipt of Application',
#  'Level 2 - Process Area: Order Processing',
#  'Procurement of Work Equipment',
#  'Procure parts',
#  'Verify applicant',
#  'Level 1 - Value Chain ACME AG',
#  'Level  2 - Process Area: Human Resources',
#  'Level 2 - Process Area: Product Development',
#  'Marketing',
#  'Geco UX pag02 new',
#  'ProvaItinere2012_2.0 (Copy)',
#  'Bancomat (Copy)',
#  'Excercise_HectorRepilloza',
#  'UML Diagram',
#  'Ex 1 (Copy)',
#  'EASY FROZEN User case (Copy)',
#  'Esempio9 (Copy)',
#  'Use case not reg Travlendar+',
#  'Class Diagram ESF',
#  'New Process',
#  'Prepare Bill',
#  'Esempio4 (Copy)',
#  'GeCo Iscrizione corso (Copy)',
#  'Submit an Order Online',
#  'RimborsoAziendale (Copy) (Copy)',
#  'ARROCK (Copy)',
#  'UX CyberSchool',
#  'MELISSA',
#  'New Diagram (Copy)12',
#  'tasktype (Copy)',
#  'EsempioTraXP',
#  'Ordine (Copy)',
#  'Exercise 6 - AlText',
#  'ArteInStrada',
#  'Rimborsi20140705 (Copy)',
#  'ACMETravel',
#  'Modify',
#  'FabbricaLib_modifiedP2',
#  'Geco UX copia',
#  'UML',
#  'ABF_Bpmn2014_2',
#  'New Process',
#  'Esempio5 (Copy)',
#  'ES 4-2',
#  'ProvaItinere2012 (Copy)',
#  'Esame13092013 (Copy)',
#  'New Diagram',
#  'BPMN',
#  'Spediscili',
#  'BCE2',
#  'Banca Prestito ES.1',
#  'Light_service (Copy)',
#  'Esercizio14',
#  'useCaseSystemManager',
#  'prova',
#  'Exercise 4',
#  'US Case',
#  'FlowerBP_VP',
#  'Notazione Associazione (Copy)',
#  'BPMN Acquisto prodotti [Sakura Production]',
#  'Esame20-07-2012',
#  'IMI Model',
#  'Light_new_complete',
#  'Transaction (Copy)',
#  'UX',
#  'UX-BCE corrispondenza',
#  'BPMN Diagram',
#  'DiagrammaCasiDUsoSistema',
#  'New ArchiMate Diagram (Copy)',
#  'Simboli (Copy)',
#  'HealthAdvisor',
#  'UX Mediolanum',
#  'Geco BCE',
#  'Rimborso spese in un azienda',
#  'useCaseUser',
#  'Receipt of Goods',
#  'BPMN acquisto (Copy)',
#  'BCE Diagram',
#  'AddPass',
#  '! Prova del 05-09-2016 (UX model)',
#  'UX diagram (Copy)',
#  'StudioMedico_UML',
#  'orGtw (Copy)',
#  'LibreriaBP_VP',
#  'Ricevi Ordine errore',
#  'ACME exercise',
#  'Ex 4.',
#  'xorGtw (Copy)',
#  'Commissione Stampa',
#  'ES 5-1',
#  'activity_diagram',
#  'EsempioDataStore (Copy)',
#  'UX',
#  'Bpmn iscrizione e pag corso',
#  'Geco UX pag01',
#  'UX Diagram',
#  'S&amp;B Cars',
#  'Ricevi Ordine errore gateway',
#  'ExamDec2020',
#  'Class Diagram Definitivo',
#  'New Process',
#  'DepositoOR (Copy)',
#  'Processo Prenotazione Studente2',
#  'Pick and Pay - Vitor R. Pereira',
#  'EsempioPOSH_EN',
#  'GreenProcess_casestudyOrchestratorFull',
#  'BPMN-PrenotazioneSoci',
#  'UX diagram (Copy) (Copy)',
#  'Verifica attivazione corso (Copy)',
#  'Class Diagram (Copy)',
#  'Esempio_Comp1 (Copy)',
#  'Flusso MyPlaces',
#  'Invio automatico toner',
#  'BozzaEsame07022014 (Copy) (Copy)',
#  'BPMN v3.0',
#  'ES 3-1',
#  'Biciclette02_02_2015-TemaB_v2 (Copy)',
#  'ProcessoAcquistoCap5v2-eng',
#  'Itinere 1',
#  'Procure work equipment',
#  'Preventivo_ENG',
#  'RimborsoAziendale (Copy)',
#  'sub-process_hierarchy (Copy)',
#  'temaB_bis2014 (Copy)',
#  'sample',
#  'BPMN-PrenotazioneSoci',
#  'GeCo Iscrizione corso f',
#  'LibreriaOrganisationVP',
#  'ItinereTraccia2_2013_2.0 (Copy)',
#  'Invia merce',
#  'BCE ESF',
#  'diagram (Copy)',
#  'ex.2',
#  'CatenaProduzione (Copy) (Copy)',
#  'Class Diagram',
#  'UX User Mobile',
#  'Exercise 3',
#  'Caffe (Copy)',
#  'New Process',
#  'GeCo Iscrizione corso 1 (Copy)',
#  'Richiesta preventivo',
#  'HamburgerBPMN_2.0 (Copy)',
#  'Insurance Claim Process',
#  'GeCo Iscrizione corso 1',
#  'Finale5Lug2013_2.0',
#  'Esempio1 (Copy)',
#  'BCE',
#  'UX TAXI DRIVER',
#  'Appello 09-02-2012',
#  'FLight_Workflow',
#  'UX User Desktop',
#  'Exercise 4',
#  'Esame13092013_2.0',
#  'BPMN_es2 (Copy)',
#  'Progetto - Crea Ordine',
#  'Rimborsi20140705',
#  "Design d'Interni Online - BPMN del Caso d'Uso: Gestione Progetto Cliente (Copy)",
#  'FabbricaLibA_2.0',
#  'FabbricaLib (Copy)',
#  'Prova',
#  'BCE ESF',
#  'UX diagram',
#  'ItinereTraccia1_2013_2.0',
#  'New Process',
#  'andGtw (Copy)',
#  'alt1 sce2',
#  'BPMN valutazione iniziativa',
#  'Exam1',
#  '5. Diagramma delle classi (Copy)',
#  'StreetArt (Copy)',
#  'Employee Onboarding',
#  'RimborsoAziendale',
#  'ES 5-3',
#  'Diagramma delle classi',
#  'New Thesis Architecture (Copy)',
#  'Receipt of Goods',
#  'Employee Onboarding',
#  'GreenProcess_casestudyOrchestratorL1',
#  'Supermarket',
#  'Esame20-07-2012 (Copy)',
#  'EX 4',
#  'A',
#  'Esempio12 (Copy)',
#  'New Process',
#  'POSH_real',
#  'Acquisto piattaforma ecommerce',
#  'User Experience ',
#  'RFQ_BPMN10-06-2012 (Copy)',
#  'BancaPrestito',
#  'CondMngBPMN19_02_2015 (Copy)',
#  'Use-case &quot;Alpine Ibex Gym&quot;',
#  'BorsaLavoro',
#  'Employee Onboarding',
#  'esempio12ter (Copy)',
#  'UX diagram',
#  'class',
#  'Class Diagram',
#  'BCE',
#  'Eduardo Costa Ex.2 ACME',
#  'bpmn tutor',
#  'Acquisto piattaforma ecommerce2017',
#  'HamburgerBPMN (Copy)',
#  'Ex 1',
#  'Ex1 Pick&amp;Pay',
#  'UX diagram (Copy) (Copy)',
#  'ACME',
#  'BackupCRM (Copy)',
#  'Ux (Copy) (Copy)',
#  "Design d'Interni Online (Copy)",
#  'ObiettivoCreativo_UseCase',
#  'Prestito',
#  'BPMN es 4',
#  'GeCo Iscrizione corso',
#  'EsempioTraXP (Copy)',
#  'Receipt of Goods',
#  'receive order',
#  'UseCaseProgetto',
#  'Esempio11bis (Copy)',
#  'ItinereTraccia1_2013_2.0 (Copy)',
#  'HamburgerBPMN_2.0',
#  'Grafico Struttura database',
#  'ProvaItinere2012_2.0',
#  'BPMN_es5',
#  'Use CAse',
#  'FlightBookingOrchestrator',
#  'Test',
#  'Association (Copy)',
#  'SupermercatoUML',
#  'loops (Copy)',
#  'Light_new_part1',
#  'ReimbursementProcess (Copy) (Copy)',
#  'MBO_BPMN_2021',
#  'Acquisto piattaforma ecommerce (Copy)',
#  'UX CyberSchool (Copy)',
#  'BPMN_es2',
#  'UX Mario Cars',
#  'Use Case Diagram',
#  'Prepare Bill',
#  'UX FMBCA',
#  'Banca Prestito ES.1 (Copy)',
#  'GestioneOrdineTransazioni',
#  'ArteInStrada (Copy)',
#  'MyMuffin-items descriptions included',
#  'ProcessoAcquistoCap5v2-eng',
#  'ProcessWithGateway',
#  'ClassDiagram_PortPharm-Online',
#  'trial-exam-Pick&amp;Pay-eng',
#  'New Process',
#  'archi alt 1 sce1',
#  'BPM gruppo 3',
#  'UML Diagram',
#  'Sol-MIP-BPMN',
#  'HamburgerBPMN',
#  'Exercise 6 - AlText',
#  'Ex 2 try',
#  '5. Diagramma delle classi',
#  'myTaxiService Use Cases',
#  'U2Bike (Copy)',
#  'BCE easyfrozen',
#  'EsempioTraXP_EN',
#  'Esempio11 (Copy)',
#  'Gestione dei problemi riscontrati da un cliente',
#  'Eduardo Costa Ex.1\xa0Pick&amp;Pay ',
#  'Waiting for responses',
#  'complexGtw (Copy)',
#  'Flusso RDA -TO BE',
#  'CTA-Diagramma-classi',
#  'connection',
#  'AutoscuolaBPMN_2.0',
#  'Sign Up Coreography',
#  'PennaCalamaio (Copy)',
#  'Exercise 2',
#  'BPMN iscrizione iniziativa',
#  'Iscizione',
#  'Amministrazione associazione XP',
#  'prova2',
#  'New Value Chain',
#  'FabbricaLibA_2.0 (Copy)',
#  'relazioni Screen-Boundary',
#  'Esempio8 (Copy)',
#  'New Process (Copy)',
#  'UX',
#  'Submit an Order at the Store',
#  'Supermercato_BPMN',
#  'StreetArt_modifiedP1',
#  'New Process',
#  'FlowerAppCoperation',
#  'Progetto - Gestione Rifornimenti',
#  'OrtoCasa2017',
#  'CTA-registrazione',
#  'New Process',
#  'Acquisto piattaforma ecommerce (Copy)',
#  'Processo di gestione di un ordine BIS',
#  'BCE diagram',
#  'Employee Onboarding',
#  'Procure work equipment',
#  'CTA-UX 4',
#  'Esempio6 (Copy)',
#  'New Diagram (Copy)5rr76r6',
#  'Add event2.0',
#  'EsempioInputOutput (Copy)',
#  'DataStoreOperations (Copy)',
#  'StreetArt_modified',
#  'BPMN-RichiestaSupporto',
#  'ES 2-2',
#  'BCE',
#  'BorsaLavoro (Copy)',
#  'Order Transfer',
#  'DiagrammaClassi',
#  'PSD Coreography Overview',
#  'Esempio1 (Copy)',
#  'ES 5-2',
#  'Use Case',
#  'StudioMedico_BPMN',
#  'New ArchiMate Diagram (Copy)jbjhb',
#  'Employee Onboarding',
#  'UX diagram',
#  'New Process',
#  'Light',
#  'OrderManagement_v3 (Copy) (Copy)',
#  '2a prova itinere - spediscili',
#  'UX COMPONENTS',
#  'Slow Food',
#  'Gestione delle esibizioni degli artisti di strada',
#  'BookLovers - Business Process Viewpoint',
#  'Exercise 5 - MagiMug',
#  'ProcessoAcquistoCap5v3',
#  'Architettura fisica (Copy)',
#  'BPMN_es4',
#  'BPMN PSD PROJECT (Copy)2',
#  'sub-process_functional (Copy)',
#  'Esempio7 (Copy)',
#  'MATES class diagram',
#  'OrderLoop_Eng',
#  'CTA-BCE',
#  'Process2ActivitiesManual',
#  'Architettura fisica',
#  'BCE Diagram Definitivo',
#  'Biciclette02_02_2015-TemaA_v2 (Copy)',
#  'S&amp;BCARS',
#  'CTA-UX 3',
#  'UseCase [Sakura Production]',
#  'associazione (Copy)',
#  'BPMN Gestione Orario',
#  'Use case auth Travlendar+',
#  'esempio12ter',
#  "Consultazione 'schede opere/eventi' personalizzate",
#  'Esame13092013_2.0 (Copy)',
#  'Exercise 1 (Copy)',
#  'FabbricaLibB_2.0',
#  'LibreriaAppCoperation',
#  'CFOOD exercise ',
#  'ItinereTraccia1_2013 (Copy)',
#  'AutoscuolaBPMN (Copy)',
#  'timeliness',
#  'uxTravelendar',
#  'Processo di Prenotazione Studente v2.1',
#  'FlowerLayered_VP',
#  'Order Placement',
#  'Bancomat_v2 (Copy)',
#  'UX PASSENGER',
#  'Processo di Prenotazione Studente 2.1',
#  'ES W3',
#  'Exercise 3 – Recruitment process',
#  'Bpmn',
#  'Esempio10 (Copy)',
#  'Use case software2',
#  'use Case',
#  'RFQ_BPMN10-06-2012',
#  'ux easy frozen',
#  'GoldenEggs',
#  'FabbricaLib',
#  'prova1',
#  'Exercise 4 – waiting for responses',
#  'New Process',
#  'Inserimento Guidato',
#  'Comitato di redazione',
#  'Handle Payment',
#  'BCE ESF (Copy)',
#  'Use case not auth Travlendar+',
#  'BCE',
#  'Ux easy frozen (Copy)',
#  'BPMN RICONOSCIEMENTO FOTO',
#  'Esame22072013 (Copy)',
#  'User Experience  (Copy)',
#  'DiagrammaER',
#  '!!! Prova del 21-07-2015 (UX model)',
#  'Virgo',
#  'Processo acquisto librerie personalizzate',
#  'Campagna Roche su Paginemediche',
#  'LibreriaLayered_VP',
#  'sottoprocesso',
#  'BPMN Gestione Orario (Copy)',
#  'New Process',
#  'ClassDiagram',
#  'Light Prima versione',
#  "Design d'Interni Online - BPMN del Caso d'Uso: Gestione Progetto Cliente",
#  'New Process',
#  'EASY FROZEN User case',
#  'FabbricaLib_mod',
#  'PowerEnjoy_BCE_Operator',
#  'MCC Architecture V1',
#  'bpmnPOOL',
#  'UseCase Diagram Definitivo',
#  'Prova del 27-01-2020 - TEMA A - Esercizio 5 - Soluzione',
#  'SupermercatoPick&amp;Pay (Simple) (Copy)',
#  'Geco UX pag01 copia',
#  'SpeedDelivery',
#  'New Process (Copy)',
#  'alt 2 sce 2',
#  'Trial Exam - exercise 1',
#  'BCE Diagram',
#  'myTaxiService - Class Diagram',
#  'FlowerTecnical',
#  'ES 2-3',
#  'Order Management',
#  'receive order (Copy)',
#  'BCE easyfrozen (Copy)',
#  'Exercise 2 (Copy)',
#  'Pick&amp;Pat (Copy)',
#  'BCE mytaxiservice',
#  'Use case',
#  'BPMN (Copy)',
#  'LibreriaTecnical',
#  'UX',
#  'StreetArt_modified',
#  'Finale5Lug2013_2.0 (Copy)',
#  'LibreriaTecnical',
#  '!!! Prova del 21-07-2015 (urgente)',
#  'BCE 2',
#  'ES 3-1',
#  'UNIMORE_ESERCIZIO_1',
#  'FlightReservationCompensated (Copy) (Copy)',
#  'DataStore (Copy)',
#  'InputOuput (Copy)',
#  'classDiagram',
#  'Esempio1bis (Copy)',
#  'Ex 1',
#  'UseCase1.0',
#  'EsempioInputOutput_ENG',
#  'Architettura fisica',
#  'Gestione rimborsi',
#  'BPMN iscrizione iniziativa (Copy)',
#  'Electronic_Eng',
#  'Esame19022015 English (Copy)',
#  'Acquisto su una piattaforma di e-commerce',
#  'GreenProcess_casestudyL1',
#  'UX',
#  'Tema A_Itinere2012 (Copy) (Copy)',
#  'UX easyfrozen (Copy)',
#  'Login',
#  'post-locations tois',
#  'Esempio11ter (Copy)',
#  'Assigment 2',
#  'CarIncident (Copy) (Copy)',
#  'OreoSubProcess (Copy)',
#  'ste',
#  'LogIn (Copy) (Copy)',
#  'DiagrammaER',
#  'Dolomiti Resort Use Case Diagram',
#  'ExampleGrouping',
#  'EsempioTTU_EN',
#  'Geco UX pag01 (Copy)',
#  'PrenotazioneViaggi (Copy) (Copy)',
#  'US Case (Copy)',
#  'Ex 4',
#  'Processo di gestione di un ordine',
#  'SubP Verifica attivazione corso',
#  'Giocatore - BPMN - iscrizione torneo',
#  'GeCo Iscrizione corso f 1',
#  'UX diagram ESF',
#  'Ux',
#  'Exercise 1 - Manuel Bertola',
#  'use case diagram',
#  'RimborsoAziendale (Copy)',
#  'Marketing (Copy)',
#  'Loop with XOR',
#  'UseCaseDiagram',
#  '20140505A (Copy)',
#  'BCE Mario Cars',
#  'U2Bike',
#  'Roche campaign on Paginemediche - Doctors',
#  'Light',
#  'FabbricaLib_modified',
#  'GreenProcess_casestudyOrchestratorSmall',
#  'BPMN-RichiestaSupporto',
#  'New Process',
#  'BCE (Copy)',
#  'SE2',
#  'ES 4-3',
#  'GeCo Iscrizione corso 2 (Copy)',
#  'Submit a Quote Coreography',
#  'Process2Activities',
#  'Commissione Stampa',
#  'Log In Coreography',
#  'Esempio_comp2 (Copy)',
#  'GeCo Iscrizione corso f 2',
#  'MyMuffin-items descriptions included (Copy)',
#  'Processo vendita librerie personalizzate',
#  'Esame22072013',
#  'BPMN (Copy)',
#  'package',
#  'Es 2 - esercit3 ',
#  'Example',
#  'GreenProcess_casestudy',
#  'Prenotazione Macchinario',
#  'New Diagram (Copy)',
#  'Use Case CR',
#  'WelcomeOffice',
#  'Class Diagram (Copy)',
#  'ProcessoAcquistoCap5v1',
#  'EasyShipping - BCE',
#  'ES w4',
#  'New Diagram (Copy)',
#  'CTA-Prenotazione+Iscrizione',
#  '!! Prova del 08-09-2015',
#  'New Process',
#  'Light_new_part1_frontend',
#  'Class Diagram ESF (Copy)',
#  'New Process',
#  'Esempio2 (Copy)',
#  '!Prova del 02-05-2016 (Tema A)',
#  'GeCo Iscrizione corso f (Copy)',
#  'Esempio12bis (Copy)',
#  'Gestione Prenotazione Studente',
#  'S&amp;BCARS (Copy)',
#  '!!! Prova del 10-07-2012 (UX model)',
#  'S&amp;B CARS (Copy)',
#  'ACMEViaggi_2.0',
#  'Esempio_trans1 (Copy)',
#  'SubP Aggiornamento N Partecipanti',
#  'Prenotazione Car Sharing (Copy)',
#  'ABF_Bpmn2014_2 (Copy)',
#  'Unknown-6',
#  'BookLovers - Organization Viewpoint',
#  'BPMN',
#  'Esercizio14 (Copy)',
#  'EsempioTech',
#  'LoanManagement (Copy) (Copy)',
#  'BPMN Lorenzo',
#  'CTA-UX 2',
#  'MyMuffin',
#  'New Process',
#  'BPMN Progetto',
#  'UX Diagram Definitivo',
#  'ES 4-1',
#  'S&amp;B CARS',
#  'Delivery at the Store',
#  'PowerEnjoy_UX_Car',
#  'SupermercatoPick&amp;Pay (Simple)',
#  'adhoc (Copy)',
#  'OrderManagement_v1 (Copy) (Copy)',
#  ...]
